# %% [markdown]
# ## Prompt Update Script
#
# Purpose of this script is to update the instructions for all 87 tasks!

# %%
import json
import os
import sys

# %%
revised_prompts = {
    0: [
    ["Based on the provided clinical text", "You may choose from the following label options: [\"Yes\", \"No\"]."],
    ["When analyzing the clinical text", "Possible values for \"label\" include: [\"Yes\", \"No\"]."],
    ["From the clinical information given", "Acceptable entries for \"label\" are: [\"Yes\", \"No\"]."],
    ["Using the clinical content provided", "\"label\" should be one of the following: [\"Yes\", \"No\"]."]
    ],

    1:  [
    ["Based on the provided clinical text", ""],
    ["When analyzing the clinical text", ""],
    ["From the clinical information given", ""],
    ["Using the clinical content provided", ""]
    ],
    
    2:  [
    ["Based on the provided clinical text", ""],
    ["When analyzing the clinical text", ""],
    ["From the clinical information given", ""],
    ["Using the clinical content provided", ""]
    ],
    
    3: [
    ["From the Spanish-language clinical text provided", ""],
    ["Using the clinical text written in Spanish", ""],
    ["Based on the patient’s clinical documentation in Spanish", ""],
    ["Taking into account the clinical content in Spanish", ""]
    ],
    
    4: [
    ["Based on a radiology report from a brain MRI", "Valid response options for 'label' are [\"Yes\", \"No\"]"],
    ["Using the results from a brain MRI radiology report", "The possible values for 'label' include [\"Yes\", \"No\"]"],
    ["From the details provided in the brain MRI report", "Acceptable entries for 'label' are [\"Yes\", \"No\"]"],
    ["Taking into account the brain MRI imaging report", "Responses for 'label' must be either [\"Yes\", \"No\"]"]
    ],
    
    5: [
    ["Using a patient's basic details and clinical notes written in Portuguese", "You may choose from the following label options: [\"Yes\", \"No\"]."],
    ["Based on the basic information and clinical notes of a patient in Portuguese", "Possible values for \"label\" include: [\"Yes\", \"No\"]."],
    ["Taking into account the clinical notes and basic patient information in Portuguese", "Acceptable entries for \"label\" are: [\"Yes\", \"No\"]."],
    ["Given a patient's clinical documentation and basic information in Portuguese", "\"label\" should be one of the following: [\"Yes\", \"No\"]."]
    ],
    
    6: [
    ["Using a patient's basic details and clinical notes written in Portuguese", "The acceptable values for \"status\" are [\"Yes\", \"No\"]"],
    ["Based on the basic information and clinical notes of a patient in Portuguese", "Valid options for \"status\" include [\"Yes\", \"No\"]"],
    ["Taking into account the clinical notes and basic patient information in Portuguese", "The \"status\" field must be either [\"Yes\", \"No\"]"],
    ["Given a patient's clinical documentation and basic information in Portuguese", "Possible entries for \"status\" are [\"Yes\", \"No\"]"]
    ],
    
    7: [
    ["Based on the clinical document written in Spanish", "The valid values for \"code\" are the normalized codes from CIE-O"],
    ["From the clinical documentation in Spanish", "Acceptable entries for \"code\" must follow the CIE-O normalization"],
    ["Given the Spanish-language clinical document", "The \"code\" field must use the standardized code from CIE-O"],
    ["Using the clinical text provided in Spanish", "The possible options for \"code\" are CIE-O normalized codes"]
    ],
    
    8: [
    ["Based on the clinical text concerning cancer written in Spanish", ""],
    ["Given the Spanish clinical note related to cancer", ""],
    ["Using the cancer-related clinical documentation in Spanish", ""],
    ["From the clinical text about cancer provided in Spanish", ""]
    ],
    
    9: [
    ["Based on the clinical text concerning cancer written in Spanish", "The valid values for \"code\" are the normalized codes from CIE-"],
    ["Given the Spanish clinical note related to cancer", "Acceptable entries for \"code\" must follow the CIE-O normalization"],
    ["Using the cancer-related clinical documentation in Spanish", "The \"code\" field must use the standardized code from CIE-O"],
    ["From the clinical text about cancer provided in Spanish", "The possible options for \"code\" are CIE-O normalized codes"]
    ],
    
    10: [
    ["Based on a radiology report written in Spanish", "Valid options for \"label\" are ['Columna', 'Neuro', 'Musculoskeletal', 'Body']"],
    ["Given the Spanish-language radiology report", "The acceptable values for \"label\" include ['Columna', 'Neuro', 'Musculoskeletal', 'Body']"],
    ["Using a radiology report in Spanish", "The possible entries for \"label\" are ['Columna', 'Neuro', 'Musculoskeletal', 'Body']"],
    ["From the Spanish radioloy report", "The \"label\" choices must be one of the following ['Columna', 'Neuro', 'Musculoskeletal', 'Body']"]
    ],

    11: [
    ["Based on a radiology report written in Spanish", ""],
    ["Given the Spanish-language radiology report", ""],
    ["Using a radiology report in Spanish", ""],
    ["From the Spanish radioloy report", ""]
    ],

    12: [
    ["Based on a radiology report written in Spanish", "Valid options for \"code\" include [\"I\", \"II\", \"III\", \"IV\", \"V\", \"VI\", \"VII\", \"VIII\", \"IX\", \"X\", \"XI\", \"XII\", \"XIII\", \"XIV\", \"XV\", \"XVI\", \"XVII\", \"XVIII\", \"XIX\", \"XX\", \"XXI\", \"XXII\"]"],
    ["Given the Spanish-language radiology report", "The acceptable list for \"code\" is [\"I\", \"II\", \"III\", \"IV\", \"V\", \"VI\", \"VII\", \"VIII\", \"IX\", \"X\", \"XI\", \"XII\", \"XIII\", \"XIV\", \"XV\", \"XVI\", \"XVII\", \"XVIII\", \"XIX\", \"XX\", \"XXI\", \"XXII\"]"],
    ["Using a radiological report in Spanish", "Permissible values for \"code\" are [\"I\", \"II\", \"III\", \"IV\", \"V\", \"VI\", \"VII\", \"VIII\", \"IX\", \"X\", \"XI\", \"XII\", \"XIII\", \"XIV\", \"XV\", \"XVI\", \"XVII\", \"XVIII\", \"XIX\", \"XX\", \"XXI\", \"XXII\"]"],
    ["From the radiology report written in Spanish", "The list of valid \"code\" values includes [\"I\", \"II\", \"III\", \"IV\", \"V\", \"VI\", \"VII\", \"VIII\", \"IX\", \"X\", \"XI\", \"XII\", \"XIII\", \"XIV\", \"XV\", \"XVI\", \"XVII\", \"XVIII\", \"XIX\", \"XX\", \"XXI\", \"XXII\"]"]
    ],

    13: [
    ["Based on a radiology report written in Spanish", ""],
    ["Given the Spanish-language radiology report", ""],
    ["Using a radiology report in Spanish", ""],
    ["From the Spanish radioloy report", ""]
    ],


    14: [
    ["Based on clinical text extracted from electronic health records in Chinese", 
     "Valid options for \"status\" are [\"肯定\", \"否定\", \"不确定\"]; use \"[]\" if no description or location is provided; list multiple entries separated by commas, e.g., [..., ...]."],

    ["Given the Chinese clinical notes from electronic medical records", 
     "Acceptable values for \"status\" include [\"肯定\", \"否定\", \"不确定\"]; if a description or location is missing, use \"[]\"; for multiple entries, separate them with commas like [..., ...]."],

    ["Using electronic healthcare record text in Chinese", 
     "\"status\" must be one of [\"肯定\", \"否定\", \"不确定\"]; if no location or description is available, write \"[]\"; use comma-separated format [..., ...] for multiple entries."],

    ["From the clinical documentation in Chinese sourced from electronic health records", 
     "The \"status\" field should be [\"肯定\", \"否定\", \"不确定\"]; write \"[]\" when there is no description or location; if there are several, list them as [..., ...] with commas."]
    ],


    15: [
    ["Based on a clinical electronic health records (EHR) written in Chinese", 
     "Valid values for \"disease\" include [\"胃息肉\", \"泌尿道感染\", \"慢性阻塞性肺病\", \"痛风\", \"胃溃疡\", \"高血压\", \"哮喘\", \"胃炎\", \"心律失常\", \"糖尿病\"]"],

    ["Given the electronic health record (EHR) in Chinese", 
     "Acceptable options for \"disease\" are [\"胃息肉\", \"泌尿道感染\", \"慢性阻塞性肺病\", \"痛风\", \"胃溃疡\", \"高血压\", \"哮喘\", \"胃炎\", \"心律失常\", \"糖尿病\"]"],

    ["Using the clinical electronic medical record written in Chinese", 
     "The optional entries for \"disease\" are [\"胃息肉\", \"泌尿道感染\", \"慢性阻塞性肺病\", \"痛风\", \"胃溃疡\", \"高血压\", \"哮喘\", \"胃炎\", \"心律失常\", \"糖尿病\"]"],

    ["From the Chinese-language clinical electronic health record", 
     "The only permissible \"disease\" values include [\"胃息肉\", \"泌尿道感染\", \"慢性阻塞性肺病\", \"痛风\", \"胃溃疡\", \"高血压\", \"哮喘\", \"胃炎\", \"心律失常\", \"糖尿病\"]"]
    ],

    16: [
    ["Based on the clinical text of a patient written in Spanish", ""],
    ["Given a patient's clinical documentation in Spanish", ""],
    ["Using the Spanish clinical text for a patient", ""], 
    ["From the clinical notes provided in Spanish for a patient", ""]
    ],

    17: [
    ["Based on the clinical text of a patient written in Spanish", ""],
    ["Given a patient's clinical documentation in Spanish", ""],
    ["Using the Spanish clinical text for a patient", ""], 
    ["From the clinical notes provided in Spanish for a patient", ""]
    ],


    18: [
    ["Based on a sentence extracted from clinical notes", "Valid options for \"label\" are [\"Yes\", \"No\"]"],
    ["Given a single sentence taken from clinical notes", "The acceptable values for \"label\" include [\"Yes\", \"No\"]"],
    ["Using a sentence from the clinical documentation", "The only permissible entries for \"label\" are [\"Yes\", \"No\"]"],
    ["From one sentence within the clinical notes", "The possible values for \"label\" are [\"Yes\", \"No\"]"]
    ],

    19: [
    ["Based on the clinical text of a patient written in Spanish", "Valid options for \"label\" are [\"pneumonia\", \"thromboembolism\", \"control\"]"],
    ["Given a patient's clinical documentation in Spanish", "The acceptable values for \"label\" include [\"pneumonia\", \"thromboembolism\", \"control\"]"],
    ["Using the Spanish clinical text for a patient", "The only permissible entries for \"label\" are [\"pneumonia\", \"thromboembolism\", \"control\"]"],
    ["From the clinical notes provided in Spanish for a patient", "Possible \"label\" values are [\"pneumonia\", \"thromboembolism\", \"control\"]"]
    ],

    20: [
    ["Based on the clinical text of a patient written in Portuguese", 
     "Valid options for \"type\" include [\"characterization\", \"test\", \"evolution\", \"genetics\", \"anatomical Site\", \"negation\", \"additional observations\", \"condition\", \"results\", \"dateTime\", \"therapeutics\", \"value\", \"route of administration\"]"],

    ["Given a patient's clinical documentation in Portuguese", 
     "The acceptable list for \"type\" is [\"characterization\", \"test\", \"evolution\", \"genetics\", \"anatomical Site\", \"negation\", \"additional observations\", \"condition\", \"results\", \"dateTime\", \"therapeutics\", \"value\", \"route of administration\"]"],

    ["Using the clinical notes of a patient in Portuguese", 
     "Permissible entries for \"type\" are [\"characterization\", \"test\", \"evolution\", \"genetics\", \"anatomical Site\", \"negation\", \"additional observations\", \"condition\", \"results\", \"dateTime\", \"therapeutics\", \"value\", \"route of administration\"]"],

    ["From the Portuguese-language clinical text of a patient", 
     "Possible values for \"type\" include [\"characterization\", \"test\", \"evolution\", \"genetics\", \"anatomical Site\", \"negation\", \"additional observations\", \"condition\", \"results\", \"dateTime\", \"therapeutics\", \"value\", \"route of administration\"]"]
    ],

    21: [
    ["Based on the patient's discharge summary", 
     "Valid choices for \"item\" are [\"Patient Instructions\", \"Appointment\", \"Medications\", \"Lab\", \"Procedure\", \"Imaging\", \"Other\"]"],

    ["Given a discharge summary for the patient", 
     "The optional values for \"item\" include [\"Patient Instructions\", \"Appointment\", \"Medications\", \"Lab\", \"Procedure\", \"Imaging\", \"Other\"]"],

    ["Using the discharge report of a patient", 
     "Acceptable options for \"item\" are [\"Patient Instructions\", \"Appointment\", \"Medications\", \"Lab\", \"Procedure\", \"Imaging\", \"Other\"]"],

    ["From the patient’s discharge documentation", 
     "Possible entries for \"item\" are [\"Patient Instructions\", \"Appointment\", \"Medications\", \"Lab\", \"Procedure\", \"Imaging\", \"Other\"]"]
    ],

    22: [
    ["Based on the medical consultation written in Chinese", ""],
    ["Given a medical consultation documented in Chinese", ""],
    ["Using the Chinese-language medical consultation", ""],
    ["From the medical consultation note in Chinese", ""]
    ],

    23: [
    ["Based on the medical consultation written in Chinese", 
     "Valid options for \"label\" are: [\"酮康唑\", \"板蓝根\", \"右美沙芬\", \"莫沙必利\", \"风寒感冒颗粒\", \"双黄连口服液\", \"蒲地蓝消炎口服液\", \"水飞蓟素\", \"米诺环素\", \"氯雷他定\", \"布地奈德\", \"苏黄止咳胶囊\", \"胶体果胶铋\", \"哈西奈德\", \"谷胱甘肽\", \"二硫化硒\", \"泰诺\", \"硫磺皂\", \"对乙酰氨基酚\", \"奥司他韦\", \"甘草酸苷\", \"红霉素\", \"西替利嗪\", \"克拉霉素\", \"氢化可的松\", \"复方甲氧那明胶囊\", \"三九胃泰\", \"替诺福韦\", \"健胃消食片\", \"炉甘石洗剂\", \"蒙脱石\", \"曲美布汀\", \"阿奇霉素\", \"扶正化瘀胶囊\", \"依巴斯汀\", \"感冒灵\", \"他克莫司\", \"氨溴索\", \"康复新液\", \"多烯磷脂酰胆碱\", \"恩替卡韦\", \"桉柠蒎肠溶软胶囊\", \"曲安奈德\", \"甘草片\", \"左氧氟沙星\", \"奥美拉唑\", \"铝镁化合物\", \"复方消化酶\", \"头孢类\", \"甲氧氯普胺\", \"地塞米松\", \"美沙拉秦\", \"双环醇\", \"肠炎宁\", \"抗病毒颗粒\", \"阿莫西林\", \"川贝枇杷露\", \"谷氨酰胺\", \"山莨菪碱\", \"阿达帕林\", \"孟鲁司特\", \"糠酸莫米松\", \"快克\", \"布洛芬\", \"益生菌\", \"通窍鼻炎颗粒\", \"阿昔洛韦\", \"生理氯化钠溶液\", \"连花清瘟胶囊\", \"黄连素\"]."],
    ["Given a medical consultation documented in Chinese", 
     "The acceptable values for \"label\" include: [\"酮康唑\", \"板蓝根\", \"右美沙芬\", \"莫沙必利\", \"风寒感冒颗粒\", \"双黄连口服液\", \"蒲地蓝消炎口服液\", \"水飞蓟素\", \"米诺环素\", \"氯雷他定\", \"布地奈德\", \"苏黄止咳胶囊\", \"胶体果胶铋\", \"哈西奈德\", \"谷胱甘肽\", \"二硫化硒\", \"泰诺\", \"硫磺皂\", \"对乙酰氨基酚\", \"奥司他韦\", \"甘草酸苷\", \"红霉素\", \"西替利嗪\", \"克拉霉素\", \"氢化可的松\", \"复方甲氧那明胶囊\", \"三九胃泰\", \"替诺福韦\", \"健胃消食片\", \"炉甘石洗剂\", \"蒙脱石\", \"曲美布汀\", \"阿奇霉素\", \"扶正化瘀胶囊\", \"依巴斯汀\", \"感冒灵\", \"他克莫司\", \"氨溴索\", \"康复新液\", \"多烯磷脂酰胆碱\", \"恩替卡韦\", \"桉柠蒎肠溶软胶囊\", \"曲安奈德\", \"甘草片\", \"左氧氟沙星\", \"奥美拉唑\", \"铝镁化合物\", \"复方消化酶\", \"头孢类\", \"甲氧氯普胺\", \"地塞米松\", \"美沙拉秦\", \"双环醇\", \"肠炎宁\", \"抗病毒颗粒\", \"阿莫西林\", \"川贝枇杷露\", \"谷氨酰胺\", \"山莨菪碱\", \"阿达帕林\", \"孟鲁司特\", \"糠酸莫米松\", \"快克\", \"布洛芬\", \"益生菌\", \"通窍鼻炎颗粒\", \"阿昔洛韦\", \"生理氯化钠溶液\", \"连花清瘟胶囊\", \"黄连素\"]."],
    ["Using the Chinese-language medical consultation", 
     "The only permissible entries for \"label\" are [\"酮康唑\", \"板蓝根\", \"右美沙芬\", \"莫沙必利\", \"风寒感冒颗粒\", \"双黄连口服液\", \"蒲地蓝消炎口服液\", \"水飞蓟素\", \"米诺环素\", \"氯雷他定\", \"布地奈德\", \"苏黄止咳胶囊\", \"胶体果胶铋\", \"哈西奈德\", \"谷胱甘肽\", \"二硫化硒\", \"泰诺\", \"硫磺皂\", \"对乙酰氨基酚\", \"奥司他韦\", \"甘草酸苷\", \"红霉素\", \"西替利嗪\", \"克拉霉素\", \"氢化可的松\", \"复方甲氧那明胶囊\", \"三九胃泰\", \"替诺福韦\", \"健胃消食片\", \"炉甘石洗剂\", \"蒙脱石\", \"曲美布汀\", \"阿奇霉素\", \"扶正化瘀胶囊\", \"依巴斯汀\", \"感冒灵\", \"他克莫司\", \"氨溴索\", \"康复新液\", \"多烯磷脂酰胆碱\", \"恩替卡韦\", \"桉柠蒎肠溶软胶囊\", \"曲安奈德\", \"甘草片\", \"左氧氟沙星\", \"奥美拉唑\", \"铝镁化合物\", \"复方消化酶\", \"头孢类\", \"甲氧氯普胺\", \"地塞米松\", \"美沙拉秦\", \"双环醇\", \"肠炎宁\", \"抗病毒颗粒\", \"阿莫西林\", \"川贝枇杷露\", \"谷氨酰胺\", \"山莨菪碱\", \"阿达帕林\", \"孟鲁司特\", \"糠酸莫米松\", \"快克\", \"布洛芬\", \"益生菌\", \"通窍鼻炎颗粒\", \"阿昔洛韦\", \"生理氯化钠溶液\", \"连花清瘟胶囊\", \"黄连素\"]."],
    ["From the medical consultation note in Chinese",
     "The list of valid \"label\" values is: \"label\" are: [\"酮康唑\", \"板蓝根\", \"右美沙芬\", \"莫沙必利\", \"风寒感冒颗粒\", \"双黄连口服液\", \"蒲地蓝消炎口服液\", \"水飞蓟素\", \"米诺环素\", \"氯雷他定\", \"布地奈德\", \"苏黄止咳胶囊\", \"胶体果胶铋\", \"哈西奈德\", \"谷胱甘肽\", \"二硫化硒\", \"泰诺\", \"硫磺皂\", \"对乙酰氨基酚\", \"奥司他韦\", \"甘草酸苷\", \"红霉素\", \"西替利嗪\", \"克拉霉素\", \"氢化可的松\", \"复方甲氧那明胶囊\", \"三九胃泰\", \"替诺福韦\", \"健胃消食片\", \"炉甘石洗剂\", \"蒙脱石\", \"曲美布汀\", \"阿奇霉素\", \"扶正化瘀胶囊\", \"依巴斯汀\", \"感冒灵\", \"他克莫司\", \"氨溴索\", \"康复新液\", \"多烯磷脂酰胆碱\", \"恩替卡韦\", \"桉柠蒎肠溶软胶囊\", \"曲安奈德\", \"甘草片\", \"左氧氟沙星\", \"奥美拉唑\", \"铝镁化合物\", \"复方消化酶\", \"头孢类\", \"甲氧氯普胺\", \"地塞米松\", \"美沙拉秦\", \"双环醇\", \"肠炎宁\", \"抗病毒颗粒\", \"阿莫西林\", \"川贝枇杷露\", \"谷氨酰胺\", \"山莨菪碱\", \"阿达帕林\", \"孟鲁司特\", \"糠酸莫米松\", \"快克\", \"布洛芬\", \"益生菌\", \"通窍鼻炎颗粒\", \"阿昔洛韦\", \"生理氯化钠溶液\", \"连花清瘟胶囊\", \"黄连素\"]."],
    ],
    
    24: [
    ["Based on the clinical text of a patient written in Spanish", "Valid options for \"type\" are [\"NAME\", \"DIR\", \"LOC\", \"NUM\", \"FECHA\", \"INST\"]"],
    ["Given a patient's clinical documentation in Spanish", "The acceptable values for \"type\" include [\"NAME\", \"DIR\", \"LOC\", \"NUM\", \"FECHA\", \"INST\"]"],
    ["Using the Spanish-language clinical notes of a patient", "The only permissible entries for \"type\" are [\"NAME\", \"DIR\", \"LOC\", \"NUM\", \"FECHA\", \"INST\"]"],
    ["From the clinical notes in Spanish for a patient", "The list of valid \"type\" values is [\"NAME\", \"DIR\", \"LOC\", \"NUM\", \"FECHA\", \"INST\"]"]
    ],

    25: [
    ["Based on the medical consultation written in Chinese", ""],
    ["Given a Chinese-language medical consultation", ""],
    ["Using the medical consultation note in Chinese", ""],
    ["From the clinical consultation documented in Chinese", ""]
    ],

    26: [
    ["Based on the medical consultation record written in Chinese,", 
     "Valid options for \"label\" are [\"儿科\", \"妇产科\", \"传染病科\", \"皮肤性病科\", \"外科\", \"内科\", \"五官科\"]"],

    ["Given a patient's medical consultation record in Chinese,", 
     "The acceptable values for \"label\" include [\"儿科\", \"妇产科\", \"传染病科\", \"皮肤性病科\", \"外科\", \"内科\", \"五官科\"]"],

    ["Using the Chinese-language medical consultation record,", 
     "The only permissible entries for \"label\" are [\"儿科\", \"妇产科\", \"传染病科\", \"皮肤性病科\", \"外科\", \"内科\", \"五官科\"]"],

    ["From the clinical consultation note written in Chinese,", 
     "The list of valid \"label\" values are [\"儿科\", \"妇产科\", \"传染病科\", \"皮肤性病科\", \"外科\", \"内科\", \"五官科\"]"]
    ],

    27: [
    ["Based on the patient's information and consultation record written in Chinese", ""],
    ["Given the consultation note and patient details in Chinese", ""],
    ["Using the patient's data and medical consultation documented in Chinese", ""],
    ["From the Chinese-language consultation record and patient information", ""]
    ],

    28: [
    ["Based on the medical consultation record written in Chinese", 
     "Valid options for \"label\" are [\"泌尿外科\", \"性病科\", \"胃肠外科\", \"肝胆外科\", \"骨科\", \"小儿内科\", \"妇科\", \"小儿精神科\", \"普外科\", \"其他传染病\", \"皮肤病\", \"消化内科\", \"风湿免疫科\", \"口腔科\", \"产科\", \"肝病科\", \"肛肠外科\", \"肾内科\", \"眼科\", \"血管外科\", \"小儿外科\", \"乳腺外科\", \"心胸外科\", \"烧伤科\", \"血液科\", \"内分泌科\", \"新生儿科\", \"神经外科\", \"呼吸内科\"]"],

    ["Given a Chinese-language medical consultation record", 
     "The acceptable values for \"label\" include [\"泌尿外科\", \"性病科\", \"胃肠外科\", \"肝胆外科\", \"骨科\", \"小儿内科\", \"妇科\", \"小儿精神科\", \"普外科\", \"其他传染病\", \"皮肤病\", \"消化内科\", \"风湿免疫科\", \"口腔科\", \"产科\", \"肝病科\", \"肛肠外科\", \"肾内科\", \"眼科\", \"血管外科\", \"小儿外科\", \"乳腺外科\", \"心胸外科\", \"烧伤科\", \"血液科\", \"内分泌科\", \"新生儿科\", \"神经外科\", \"呼吸内科\"]"],

    ["Using the medical consultation documentation in Chinese", 
     "Valid entries for \"label\" are [\"泌尿外科\", \"性病科\", \"胃肠外科\", \"肝胆外科\", \"骨科\", \"小儿内科\", \"妇科\", \"小儿精神科\", \"普外科\", \"其他传染病\", \"皮肤病\", \"消化内科\", \"风湿免疫科\", \"口腔科\", \"产科\", \"肝病科\", \"肛肠外科\", \"肾内科\", \"眼科\", \"血管外科\", \"小儿外科\", \"乳腺外科\", \"心胸外科\", \"烧伤科\", \"血液科\", \"内分泌科\", \"新生儿科\", \"神经外科\", \"呼吸内科\"]"],

    ["From the consultation record written in Chinese", 
     "Permissible values for \"label\" are [\"泌尿外科\", \"性病科\", \"胃肠外科\", \"肝胆外科\", \"骨科\", \"小儿内科\", \"妇科\", \"小儿精神科\", \"普外科\", \"其他传染病\", \"皮肤病\", \"消化内科\", \"风湿免疫科\", \"口腔科\", \"产科\", \"肝病科\", \"肛肠外科\", \"肾内科\", \"眼科\", \"血管外科\", \"小儿外科\", \"乳腺外科\", \"心胸外科\", \"烧伤科\", \"血液科\", \"内分泌科\", \"新生儿科\", \"神经外科\", \"呼吸内科\"]"]
    ],


    29: [
    ["Based on the following physician's explanation,", 
     "Valid options for \"type\" are [\"Condition\", \"DiagLab\", \"LabValues\", \"HealthState\", \"Measure\", \"Medication\", \"Process\", \"TimeInfo\", \"Other\"]"],

    ["Given the physician's explanation below,", 
     "The acceptable values for \"type\" include [\"Condition\", \"DiagLab\", \"LabValues\", \"HealthState\", \"Measure\", \"Medication\", \"Process\", \"TimeInfo\", \"Other\"]"],

    ["Using the following explanation from the physician,", 
     "Valid entries for \"type\" are [\"Condition\", \"DiagLab\", \"LabValues\", \"HealthState\", \"Measure\", \"Medication\", \"Process\", \"TimeInfo\", \"Other\"]"],

    ["From the physician's statement provided below,", 
     "Possible entries for \"type\" are [\"Condition\", \"DiagLab\", \"LabValues\", \"HealthState\", \"Measure\", \"Medication\", \"Process\", \"TimeInfo\", \"Other\"]"]
    ],


    30: [
    ["Based on the patient's chief complaint", "Valid options for \"label\" are [\"Yes\", \"No\"]"],
    ["Given the main complaint reported by the patient", "The optional values for \"label\" are [\"Yes\", \"No\"]"],
    ["Using the chief complaint described by the patient", "Permissible entries for \"label\" include [\"Yes\", \"No\"]"],
    ["From the patient's reported chief complaint", "Possible values for \"label\" are [\"Yes\", \"No\"]"]
    ],

    31: [
    ["Based on the clinical document of a patient", "Valid options for \"type\" include [\"PATIENT\", \"ID\", \"LOCATION\", \"AGE\", \"DOCTOR\", \"PHONE\", \"HOSPITAL\", \"DATE\"]"],
    ["Given a patient's clinical document", "The options for \"type\" include only [\"PATIENT\", \"ID\", \"LOCATION\", \"AGE\", \"DOCTOR\", \"PHONE\", \"HOSPITAL\", \"DATE\"]"],
    ["Using the clinical documentation of a patient", "Permissible values for \"type\" are [\"PATIENT\", \"ID\", \"LOCATION\", \"AGE\", \"DOCTOR\", \"PHONE\", \"HOSPITAL\", \"DATE\"]"],
    ["From the patient's clinical record", "Possible entries for \"type\" include [\"PATIENT\", \"ID\", \"LOCATION\", \"AGE\", \"DOCTOR\", \"PHONE\", \"HOSPITAL\", \"DATE\"]"]
    ],


    32: [
    ["Based on the discharge summary of a patient,", 
     "The list of options for \"list/narrative\" is [\"list\", \"narrative\"].\nIf any of the entities (\"dosage\", \"mode\", \"frequency\", \"duration\", \"reason\", \"list/narrative\") are missing from the discharge summary for a given medication, label the entity as \"not mentioned\"."],

    ["Given a patient’s discharge summary,", 
     "The allowable values for \"list/narrative\" are [\"list\", \"narrative\"].\nFor each medication extracted, if any of the entities such as \"dosage\", \"mode\", \"frequency\", \"duration\", \"reason\", or \"list/narrative\" are absent, assign them the label \"not mentioned\"."],

    ["Using the discharge summary information for a patient,", 
     "The valid entries for \"list/narrative\" include [\"list\", \"narrative\"].\nIf any of the specified entities are not found for a medication, please tag them as \"not mentioned\"."],

    ["From the discharge documentation of a patient,", 
     "The possible values for \"list/narrative\" are [\"list\", \"narrative\"].\nIf an entity (\"dosage\", \"mode\", \"frequency\", \"duration\", \"reason\", or \"list/narrative\") is missing for a medication, mark it as \"not mentioned\"."]
    ],

    33: [
    ["Based on the discharge summary of a patient,", 
     "The list of valid options for \"type\" is [\"problem\", \"treatment\", \"test\"]"],

    ["Given a patient's discharge summary,", 
     "Valid values for \"type\" are [\"problem\", \"treatment\", \"test\"]"],

    ["Using the discharge summary provided for the patient,", 
     "Permissible options for \"type\" include [\"problem\", \"treatment\", \"test\"]"],

    ["From the clinical discharge documentation of a patient,", 
     "The acceptable list for \"type\" is [\"problem\", \"treatment\", \"test\"]"]
    ],

    34: [
    ["Based on the discharge summary of a patient", 
     "Valid response options for \"type\" are [\"present\", \"absent\", \"possible\", \"conditional\", \"hypothetical\", \"not associated with patient\"]"],

    ["Given a patient's discharge summary", 
     "The possible values for \"type\" include [\"present\", \"absent\", \"possible\", \"conditional\", \"hypothetical\", \"not associated with patient\"]"],

    ["Using the discharge summary provided for the patient", 
     "Acceptable entries for \"type\" are [\"present\", \"absent\", \"possible\", \"conditional\", \"hypothetical\", \"not associated with patient\"]"],

    ["From the discharge documentation of a patient", 
     "The \"type\" must be one of [\"present\", \"absent\", \"possible\", \"conditional\", \"hypothetical\", \"not associated with patient\"]"]
    ],

    35: [
    ["Based on the discharge summary of a patient", 
     "Valid response options for \"relation\" are [\"TrIP\", \"TrWP\", \"TrCP\", \"TrAP\", \"TrNAP\", \"TeRP\", \"TeCP\", \"PIP\"]"],

    ["Given a patient's discharge summary", 
     "The possible values for \"relation\" include [\"TrIP\", \"TrWP\", \"TrCP\", \"TrAP\", \"TrNAP\", \"TeRP\", \"TeCP\", \"PIP\"]"],

    ["Using the discharge summary provided for the patient", 
     "Acceptable entries for \"relation\" are [\"TrIP\", \"TrWP\", \"TrCP\", \"TrAP\", \"TrNAP\", \"TeRP\", \"TeCP\", \"PIP\"]"],

    ["From the discharge documentation of a patient", 
     "The \"relation\" must be one of [\"TrIP\", \"TrWP\", \"TrCP\", \"TrAP\", \"TrNAP\", \"TeRP\", \"TeCP\", \"PIP\"]"]
    ],

    36: [
    ["Based on the clinical document of a patient", 
     "Valid response options for \"PHI types\" are [\"STATE\", \"LOCATION-OTHER\", \"STREET\", \"PHONE\", \"FAX\", \"ZIP\", \"DOCTOR\", \"DATE\", \"EMAIL\", \"DEVICE\", \"COUNTRY\", \"HOSPITAL\", \"HEALTHPLAN\", \"ORGANIZATION\", \"USERNAME\", \"BIOID\", \"CITY\", \"PROFESSION\", \"PATIENT\", \"URL\", \"AGE\", \"IDNUM\", \"MEDICALRECORD\"]"],

    ["Given a patient's clinical document", 
     "The possible values for \"PHI types\" include [\"STATE\", \"LOCATION-OTHER\", \"STREET\", \"PHONE\", \"FAX\", \"ZIP\", \"DOCTOR\", \"DATE\", \"EMAIL\", \"DEVICE\", \"COUNTRY\", \"HOSPITAL\", \"HEALTHPLAN\", \"ORGANIZATION\", \"USERNAME\", \"BIOID\", \"CITY\", \"PROFESSION\", \"PATIENT\", \"URL\", \"AGE\", \"IDNUM\", \"MEDICALRECORD\"]"],

    ["Using the clinical documentation of a patient", 
     "Acceptable entries for \"PHI types\" are [\"STATE\", \"LOCATION-OTHER\", \"STREET\", \"PHONE\", \"FAX\", \"ZIP\", \"DOCTOR\", \"DATE\", \"EMAIL\", \"DEVICE\", \"COUNTRY\", \"HOSPITAL\", \"HEALTHPLAN\", \"ORGANIZATION\", \"USERNAME\", \"BIOID\", \"CITY\", \"PROFESSION\", \"PATIENT\", \"URL\", \"AGE\", \"IDNUM\", \"MEDICALRECORD\"]"],

    ["From the patient’s clinical record", 
     "The \"PHI types\" must be one of [\"STATE\", \"LOCATION-OTHER\", \"STREET\", \"PHONE\", \"FAX\", \"ZIP\", \"DOCTOR\", \"DATE\", \"EMAIL\", \"DEVICE\", \"COUNTRY\", \"HOSPITAL\", \"HEALTHPLAN\", \"ORGANIZATION\", \"USERNAME\", \"BIOID\", \"CITY\", \"PROFESSION\", \"PATIENT\", \"URL\", \"AGE\", \"IDNUM\", \"MEDICALRECORD\"]"]
    ],


    37: [
    ["Based on the text from a medical consultation in Chinese", 
     "Valid response options for \"type\" are [\"symptom\", \"drug\", \"drug category\", \"examination\", \"operation\"]"],

    ["Given the Chinese medical consultation text", 
     "The possible values for \"type\" include [\"symptom\", \"drug\", \"drug category\", \"examination\", \"operation\"]"],

    ["Using the text from a clinical consultation in Chinese", 
     "Acceptable entries for \"type\" are [\"symptom\", \"drug\", \"drug category\", \"examination\", \"operation\"]"],

    ["From the Chinese-language consultation record", 
     "The \"type\" must be one of [\"symptom\", \"drug\", \"drug category\", \"examination\", \"operation\"]"]
     ],


    38: [
    ["Based on the following two clinical sentences labeled as \"Sentence A\" and \"Sentence B\" in Japanese", 
     "Valid response options for \"score\" are [\"0\", \"1\", \"2\", \"3\", \"4\", \"5\"]"],

    ["Given two clinical sentences in Japanese, referred to as \"Sentence A\" and \"Sentence B\"", 
     "The possible values for \"score\" include [\"0\", \"1\", \"2\", \"3\", \"4\", \"5\"]"],

    ["Using the clinical sentence pair labeled as \"Sentence A\" and \"Sentence B\" in Japanese", 
     "Acceptable entries for \"score\" are [\"0\", \"1\", \"2\", \"3\", \"4\", \"5\"]"],

    ["From the Japanese clinical text consisting of \"Sentence A\" and \"Sentence B\"", 
     "The \"score\" must be one of [\"0\", \"1\", \"2\", \"3\", \"4\", \"5\"]"]
    ],

    39: [
    ["Based on the clinical text of a patient in Spanish", 
     "Valid response options for \"type\" are [\"TERRITORIO\", \"FECHAS\", \"EDAD SUJETO ASISTENCIA\", \"NOMBRE SUJETO ASISTENCIA\", \"NOMBRE PERSONAL SANITARIO\", \"SEXO SUJETO ASISTENCIA\", \"CALLE\", \"PAIS\", \"ID SUJETO ASISTENCIA\", \"CORREO ELECTRONICO\", \"ID TITULACION PERSONAL SANITARIO\", \"ID ASEGURAMIENTO\", \"HOSPITAL\", \"FAMILIARES SUJETO ASISTENCIA\", \"INSTITUCION\", \"ID CONTACTO ASISTENCIAL\", \"NUMERO TELEFONO\", \"PROFESION\", \"NUMERO FAX\", \"OTROS SUJETO ASISTENCIA\", \"CENTRO SALUD\", \"ID EMPLEO PERSONAL SANITARIO\", \"IDENTIF VEHICULOS NRSERIE PLACAS\", \"IDENTIF DISPOSITIVOS NRSERIE\", \"NUMERO BENEF PLAN SALUD\", \"URL WEB\", \"DIREC PROT INTERNET\", \"IDENTF BIOMETRICOS\", \"OTRO NUMERO IDENTIF\"]"],

    ["Given a patient's clinical documentation in Spanish", 
     "The possible values for \"type\" include [\"TERRITORIO\", \"FECHAS\", \"EDAD SUJETO ASISTENCIA\", \"NOMBRE SUJETO ASISTENCIA\", \"NOMBRE PERSONAL SANITARIO\", \"SEXO SUJETO ASISTENCIA\", \"CALLE\", \"PAIS\", \"ID SUJETO ASISTENCIA\", \"CORREO ELECTRONICO\", \"ID TITULACION PERSONAL SANITARIO\", \"ID ASEGURAMIENTO\", \"HOSPITAL\", \"FAMILIARES SUJETO ASISTENCIA\", \"INSTITUCION\", \"ID CONTACTO ASISTENCIAL\", \"NUMERO TELEFONO\", \"PROFESION\", \"NUMERO FAX\", \"OTROS SUJETO ASISTENCIA\", \"CENTRO SALUD\", \"ID EMPLEO PERSONAL SANITARIO\", \"IDENTIF VEHICULOS NRSERIE PLACAS\", \"IDENTIF DISPOSITIVOS NRSERIE\", \"NUMERO BENEF PLAN SALUD\", \"URL WEB\", \"DIREC PROT INTERNET\", \"IDENTF BIOMETRICOS\", \"OTRO NUMERO IDENTIF\"]"],

    ["Using the Spanish-language clinical notes of a patient", 
     "Acceptable entries for \"type\" are [\"TERRITORIO\", \"FECHAS\", \"EDAD SUJETO ASISTENCIA\", \"NOMBRE SUJETO ASISTENCIA\", \"NOMBRE PERSONAL SANITARIO\", \"SEXO SUJETO ASISTENCIA\", \"CALLE\", \"PAIS\", \"ID SUJETO ASISTENCIA\", \"CORREO ELECTRONICO\", \"ID TITULACION PERSONAL SANITARIO\", \"ID ASEGURAMIENTO\", \"HOSPITAL\", \"FAMILIARES SUJETO ASISTENCIA\", \"INSTITUCION\", \"ID CONTACTO ASISTENCIAL\", \"NUMERO TELEFONO\", \"PROFESION\", \"NUMERO FAX\", \"OTROS SUJETO ASISTENCIA\", \"CENTRO SALUD\", \"ID EMPLEO PERSONAL SANITARIO\", \"IDENTIF VEHICULOS NRSERIE PLACAS\", \"IDENTIF DISPOSITIVOS NRSERIE\", \"NUMERO BENEF PLAN SALUD\", \"URL WEB\", \"DIREC PROT INTERNET\", \"IDENTF BIOMETRICOS\", \"OTRO NUMERO IDENTIF\"]"],

    ["From the clinical documentation in Spanish for a patient", 
     "The \"type\" must be one of [\"TERRITORIO\", \"FECHAS\", \"EDAD SUJETO ASISTENCIA\", \"NOMBRE SUJETO ASISTENCIA\", \"NOMBRE PERSONAL SANITARIO\", \"SEXO SUJETO ASISTENCIA\", \"CALLE\", \"PAIS\", \"ID SUJETO ASISTENCIA\", \"CORREO ELECTRONICO\", \"ID TITULACION PERSONAL SANITARIO\", \"ID ASEGURAMIENTO\", \"HOSPITAL\", \"FAMILIARES SUJETO ASISTENCIA\", \"INSTITUCION\", \"ID CONTACTO ASISTENCIAL\", \"NUMERO TELEFONO\", \"PROFESION\", \"NUMERO FAX\", \"OTROS SUJETO ASISTENCIA\", \"CENTRO SALUD\", \"ID EMPLEO PERSONAL SANITARIO\", \"IDENTIF VEHICULOS NRSERIE PLACAS\", \"IDENTIF DISPOSITIVOS NRSERIE\", \"NUMERO BENEF PLAN SALUD\", \"URL WEB\", \"DIREC PROT INTERNET\", \"IDENTF BIOMETRICOS\", \"OTRO NUMERO IDENTIF\"]"]
    ],

    40: [
    ["Based on the following two clinical questions labeled as \"Question A\" and \"Question B\"", 
     "Valid response options for \"label\" are [\"true\", \"false\"]"],

    ["Given the two clinical questions referred to as \"Question A\" and \"Question B\"", 
     "The possible values for \"label\" include [\"true\", \"false\"]"],

    ["Using the clinical question pair labeled as \"Question A\" and \"Question B\"", 
     "Acceptable entries for \"label\" are [\"true\", \"false\"]"],

    ["From the two clinical questions marked as \"Question A\" and \"Question B\"", 
     "The \"label\" must be one of [\"true\", \"false\"]"]
    ],

    41: [
    ["Based on the premise-hypothesis statements pair labeled as \"Premise statement\" and \"Hypothesis statement\",", 
     "Valid response options for \"label\" are [\"entailment\", \"contradiction\", \"neutral\"]"],

    ["Given the statement pair labeled as \"Premise statement\" and \"Hypothesis statement\",", 
     "The possible values for \"label\" include [\"entailment\", \"contradiction\", \"neutral\"]"],

    ["Using the premise and hypothesis labeled as \"Premise statement\" and \"Hypothesis statement\",", 
     "Acceptable entries for \"label\" are [\"entailment\", \"contradiction\", \"neutral\"]"],

    ["From the labeled pair \"Premise statement\" and \"Hypothesis statement\",", 
     "The \"label\" must be one of [\"entailment\", \"contradiction\", \"neutral\"]"]
    ],


    42: [
    ["Based on two clinical sentences labeled as \"Sentence A\" and \"Sentence B\",", 
     "Valid response options for \"score\" are [\"0\", \"1\", \"2\", \"3\", \"4\", \"5\"]"],

    ["Given the pair of clinical sentences labeled as \"Sentence A\" and \"Sentence B\",", 
     "The possible values for \"score\" include [\"0\", \"1\", \"2\", \"3\", \"4\", \"5\"]"],

    ["Using two labeled clinical sentences referred to as \"Sentence A\" and \"Sentence B\",", 
     "Acceptable entries for \"score\" are [\"0\", \"1\", \"2\", \"3\", \"4\", \"5\"]"],

    ["From the clinical sentence pair labeled \"Sentence A\" and \"Sentence B\",", 
     "The \"score\" must be one of [\"0\", \"1\", \"2\", \"3\", \"4\", \"5\"]"]
    ],


    43: [
    ["Based on the transcribed clinical text", 
     "Valid response options for \"label\" are ['Allergy / Immunology', 'Autopsy', 'Bariatrics', 'Cardiovascular / Pulmonary', 'Chiropractic', 'Consult - History and Phy.', 'Cosmetic / Plastic Surgery', 'Dentistry', 'Dermatology', 'Diets and Nutritions', 'Discharge Summary', 'ENT - Otolaryngology', 'Emergency Room Reports', 'Endocrinology', 'Gastroenterology', 'General Medicine', 'Hematology - Oncology', 'Hospice - Palliative Care', 'IME-QME-Work Comp etc.', 'Lab Medicine - Pathology', 'Letters', 'Nephrology', 'Neurology', 'Neurosurgery', 'Obstetrics / Gynecology', 'Office Notes', 'Ophthalmology', 'Orthopedic', 'Pain Management', 'Pediatrics - Neonatal', 'Physical Medicine - Rehab', 'Podiatry', 'Psychiatry / Psychology', 'Radiology', 'Rheumatology', 'SOAP / Chart / Progress Notes', 'Sleep Medicine', 'Speech - Language', 'Surgery', 'Urology']"],

    ["Given the transcribed clinical text", 
     "The possible values for \"label\" include ['Allergy / Immunology', 'Autopsy', 'Bariatrics', 'Cardiovascular / Pulmonary', 'Chiropractic', 'Consult - History and Phy.', 'Cosmetic / Plastic Surgery', 'Dentistry', 'Dermatology', 'Diets and Nutritions', 'Discharge Summary', 'ENT - Otolaryngology', 'Emergency Room Reports', 'Endocrinology', 'Gastroenterology', 'General Medicine', 'Hematology - Oncology', 'Hospice - Palliative Care', 'IME-QME-Work Comp etc.', 'Lab Medicine - Pathology', 'Letters', 'Nephrology', 'Neurology', 'Neurosurgery', 'Obstetrics / Gynecology', 'Office Notes', 'Ophthalmology', 'Orthopedic', 'Pain Management', 'Pediatrics - Neonatal', 'Physical Medicine - Rehab', 'Podiatry', 'Psychiatry / Psychology', 'Radiology', 'Rheumatology', 'SOAP / Chart / Progress Notes', 'Sleep Medicine', 'Speech - Language', 'Surgery', 'Urology']"],

    ["Using the transcribed version of the clinical text", 
     "Acceptable entries for \"label\" are ['Allergy / Immunology', 'Autopsy', 'Bariatrics', 'Cardiovascular / Pulmonary', 'Chiropractic', 'Consult - History and Phy.', 'Cosmetic / Plastic Surgery', 'Dentistry', 'Dermatology', 'Diets and Nutritions', 'Discharge Summary', 'ENT - Otolaryngology', 'Emergency Room Reports', 'Endocrinology', 'Gastroenterology', 'General Medicine', 'Hematology - Oncology', 'Hospice - Palliative Care', 'IME-QME-Work Comp etc.', 'Lab Medicine - Pathology', 'Letters', 'Nephrology', 'Neurology', 'Neurosurgery', 'Obstetrics / Gynecology', 'Office Notes', 'Ophthalmology', 'Orthopedic', 'Pain Management', 'Pediatrics - Neonatal', 'Physical Medicine - Rehab', 'Podiatry', 'Psychiatry / Psychology', 'Radiology', 'Rheumatology', 'SOAP / Chart / Progress Notes', 'Sleep Medicine', 'Speech - Language', 'Surgery', 'Urology']"],

    ["From the clinical text that has been transcribed", 
     "The \"label\" must be one of ['Allergy / Immunology', 'Autopsy', 'Bariatrics', 'Cardiovascular / Pulmonary', 'Chiropractic', 'Consult - History and Phy.', 'Cosmetic / Plastic Surgery', 'Dentistry', 'Dermatology', 'Diets and Nutritions', 'Discharge Summary', 'ENT - Otolaryngology', 'Emergency Room Reports', 'Endocrinology', 'Gastroenterology', 'General Medicine', 'Hematology - Oncology', 'Hospice - Palliative Care', 'IME-QME-Work Comp etc.', 'Lab Medicine - Pathology', 'Letters', 'Nephrology', 'Neurology', 'Neurosurgery', 'Obstetrics / Gynecology', 'Office Notes', 'Ophthalmology', 'Orthopedic', 'Pain Management', 'Pediatrics - Neonatal', 'Physical Medicine - Rehab', 'Podiatry', 'Psychiatry / Psychology', 'Radiology', 'Rheumatology', 'SOAP / Chart / Progress Notes', 'Sleep Medicine', 'Speech - Language', 'Surgery', 'Urology']"]
    ],


    44: [
    ["Based on the clinical text", 
     "Valid response options for \"category\" are [\"time\", \"frequency\", \"age_related\", \"date\", \"duration\", \"other\"]"],

    ["Given the clinical text", 
     "The possible values for \"category\" include [\"time\", \"frequency\", \"age_related\", \"date\", \"duration\", \"other\"]"],

    ["Using the provided clinical text", 
     "Acceptable entries for \"category\" are [\"time\", \"frequency\", \"age_related\", \"date\", \"duration\", \"other\"]"],

    ["From the clinical text", 
     "The \"category\" must be one of [\"time\", \"frequency\", \"age_related\", \"date\", \"duration\", \"other\"]"]
    ],


    45: [
    ["Based on the longitudinal medical records of a patient", 
     "Valid response options for \"attribute\" are [\"adverse drug event\", \"dosage\", \"duration\", \"form\", \"frequency\", \"reason\", \"route\", \"strength\"]"],

    ["Given the patient's longitudinal medical records", 
     "The possible values for \"attribute\" include [\"adverse drug event\", \"dosage\", \"duration\", \"form\", \"frequency\", \"reason\", \"route\", \"strength\"]"],

    ["Using the longitudinal health records of a patient", 
     "Acceptable entries for \"attribute\" are [\"adverse drug event\", \"dosage\", \"duration\", \"form\", \"frequency\", \"reason\", \"route\", \"strength\"]"],

    ["From the longitudinal medical documentation of a patient", 
     "The \"attribute\" must be one of [\"adverse drug event\", \"dosage\", \"duration\", \"form\", \"frequency\", \"reason\", \"route\", \"strength\"]"]
    ],


    46: [
    ["Based on the clinical text of a patient in Norwegian", 
     "Valid response options for \"type\" are [\"FAMILY\", \"SELF\", \"INDEX\", \"CONDITION\", \"EVENT\", \"SIDE\", \"AGE\", \"NEG\", \"AMOUNT\", \"EMPORAL\"]"],

    ["Given a patient's clinical text written in Norwegian", 
     "The possible values for \"type\" include [\"FAMILY\", \"SELF\", \"INDEX\", \"CONDITION\", \"EVENT\", \"SIDE\", \"AGE\", \"NEG\", \"AMOUNT\", \"EMPORAL\"]"],

    ["Using the Norwegian-language clinical text of a patient", 
     "Acceptable entries for \"type\" are [\"FAMILY\", \"SELF\", \"INDEX\", \"CONDITION\", \"EVENT\", \"SIDE\", \"AGE\", \"NEG\", \"AMOUNT\", \"EMPORAL\"]"],

    ["From the clinical documentation in Norwegian for a patient", 
     "The \"type\" must be one of [\"FAMILY\", \"SELF\", \"INDEX\", \"CONDITION\", \"EVENT\", \"SIDE\", \"AGE\", \"NEG\", \"AMOUNT\", \"EMPORAL\"]"]
    ],


    47: [
    ["Based on the clinical text of a patient in Norwegian", 
     "Valid response options for \"relation\" are [\"Holder\", \"Modifier\", \"Related_to\", \"Subset\", \"Partner\"]"],

    ["Given a patient's clinical text written in Norwegian", 
     "The possible values for \"relation\" include [\"Holder\", \"Modifier\", \"Related_to\", \"Subset\", \"Partner\"]"],

    ["Using the Norwegian-language clinical documentation of a patient", 
     "Acceptable entries for \"relation\" are [\"Holder\", \"Modifier\", \"Related_to\", \"Subset\", \"Partner\"]"],

    ["From the clinical text in Norwegian for a patient", 
     "The \"relation\" must be one of [\"Holder\", \"Modifier\", \"Related_to\", \"Subset\", \"Partner\"]"]
    ],


    48: [
    ["Based on the clinical text of a patient in Spanish", 
     "Valid response options for \"type\" are [\"NegSynMarker\", \"NegLexMarker\", \"NegMorMarker\", \"UncertSynMarker\", \"UncertLexMarker\"]"],

    ["Given a patient's clinical documentation in Spanish", 
     "The possible values for \"type\" include [\"NegSynMarker\", \"NegLexMarker\", \"NegMorMarker\", \"UncertSynMarker\", \"UncertLexMarker\"]"],

    ["Using the Spanish-language clinical text of a patient", 
     "Acceptable entries for \"type\" are [\"NegSynMarker\", \"NegLexMarker\", \"NegMorMarker\", \"UncertSynMarker\", \"UncertLexMarker\"]"],

    ["From the clinical notes in Spanish for a patient", 
     "The \"type\" must be one of [\"NegSynMarker\", \"NegLexMarker\", \"NegMorMarker\", \"UncertSynMarker\", \"UncertLexMarker\"]"]
    ],

    49: [
    ["Based on the clinical conversation between a doctor and a patient", ""],
    ["Given a dialogue between the patient and the doctor", ""],
    ["Using the medical interaction recorded between a doctor and a patient", ""],
    ["From the conversation that took place between doctor and patient", ""]
    ],

    50: [
    ["Based on the clinical conversation between a doctor and a patient", 
     "Valid response options for \"label\" are [\"family history/social history\", \"history of patient illness\", \"past medical history\", \"chief complaint\", \"past surgical history\", \"allergy\", \"review of systems\", \"medications\", \"assessment\", \"exam\", \"diagnosis\", \"disposition\", \"plan\", \"emergency department course\", \"immunizations\", \"imaging\", \"gynecologic history\", \"procedures\", \"other history\", \"labs\"]"],

    ["Given a dialogue between the patient and the doctor", 
     "The possible values for \"label\" include [\"family history/social history\", \"history of patient illness\", \"past medical history\", \"chief complaint\", \"past surgical history\", \"allergy\", \"review of systems\", \"medications\", \"assessment\", \"exam\", \"diagnosis\", \"disposition\", \"plan\", \"emergency department course\", \"immunizations\", \"imaging\", \"gynecologic history\", \"procedures\", \"other history\", \"labs\"]"],

    ["Using the medical interaction recorded between a doctor and a patient", 
     "Acceptable entries for \"label\" are [\"family history/social history\", \"history of patient illness\", \"past medical history\", \"chief complaint\", \"past surgical history\", \"allergy\", \"review of systems\", \"medications\", \"assessment\", \"exam\", \"diagnosis\", \"disposition\", \"plan\", \"emergency department course\", \"immunizations\", \"imaging\", \"gynecologic history\", \"procedures\", \"other history\", \"labs\"]"],

    ["From the conversation that took place between doctor and patient", 
     "The \"label\" must be one of [\"family history/social history\", \"history of patient illness\", \"past medical history\", \"chief complaint\", \"past surgical history\", \"allergy\", \"review of systems\", \"medications\", \"assessment\", \"exam\", \"diagnosis\", \"disposition\", \"plan\", \"emergency department course\", \"immunizations\", \"imaging\", \"gynecologic history\", \"procedures\", \"other history\", \"labs\"]"]
    ],

    51: [
    ["Based on the clinical conversation between a doctor and a patient", ""],
    ["Given a dialogue between the patient and the doctor", ""],
    ["Using the medical interaction recorded between a doctor and a patient", ""],
    ["From the conversation that took place between doctor and patient", ""]
    ],


    52: [
    ["Based on the clinical text labeled as \"Context\" and the clinical question labeled as \"Question\" in Russian", 
     "Valid response options for \"label\" are [\"yes\", \"no\"]"],

    ["Given the Russian clinical text labeled \"Context\" and the question labeled \"Question\"", 
     "The possible values for \"label\" include [\"yes\", \"no\"]"],

    ["Using the clinical input marked as \"Context\" and \"Question\" in Russian", 
     "Acceptable entries for \"label\" are [\"yes\", \"no\"]"],

    ["From the clinical passage labeled as \"Context\" and question labeled as \"Question\" in Russian", 
     "The \"label\" must be one of [\"yes\", \"no\"]"]
    ],


    53: [
    ["Based on the original diagnostic text from electronic healthcare records in Chinese,", 
     "Valid response options for \"label\" are the names of normalized terms (not code) from the 《国际疾病分类 ICD-10 北京临床版v601》, covering diagnosis, surgery, medication, examination, laboratory testing, and symptoms."],

    ["Given the diagnostic content extracted from Chinese electronic health records,", 
     "The possible values for \"label\" include the normalized term names (excluding codes) from the 《国际疾病分类 ICD-10 北京临床版v601》, spanning diagnosis, surgery, medication, examination, lab tests, and symptoms."],

    ["Using the original diagnostic entry from the Chinese electronic medical records,", 
     "Acceptable entries for \"label\" are normalized names (not codes) as defined in 《国际疾病分类 ICD-10 北京临床版v601》, including diagnoses, procedures, medications, exams, tests, and symptom descriptions."],

    ["From the diagnostic section of the Chinese electronic healthcare records,", 
     "The \"label\" must be one of the normalized terms (excluding code) listed in 《国际疾病分类 ICD-10 北京临床版v601》 for diagnosis, surgery, medication, examination, lab testing, or symptoms."]
    ],


    54: [
    ["Based on the clinical text in Chinese", 
     "Valid response options for \"label\" are [\"疾病\", \"症状-患者感受\", \"体征-医生检测\", \"怀孕相关\", \"肿瘤进展\", \"疾病分期\", \"过敏耐受\", \"器官组织状态\", \"预期寿命\", \"口腔相关\", \"药物\", \"治疗或手术\", \"设备\", \"护理\", \"诊断\", \"实验室检查\", \"风险评估\", \"受体状态\", \"年龄\", \"特殊病人特征\", \"读写能力\", \"性别\", \"教育情况\", \"居住情况\", \"种族\", \"知情同意\", \"参与其它试验\", \"研究者决定\", \"能力\", \"伦理审查\", \"依存性\", \"成瘾行为\", \"睡眠\", \"锻炼\", \"饮食\", \"酒精使用\", \"性取向\", \"吸烟状况\", \"献血\", \"病例来源\", \"残疾群体\", \"健康群体\", \"数据可及性\"]"],

    ["Given the Chinese clinical text", 
     "The possible values for \"label\" include [\"疾病\", \"症状-患者感受\", \"体征-医生检测\", \"怀孕相关\", \"肿瘤进展\", \"疾病分期\", \"过敏耐受\", \"器官组织状态\", \"预期寿命\", \"口腔相关\", \"药物\", \"治疗或手术\", \"设备\", \"护理\", \"诊断\", \"实验室检查\", \"风险评估\", \"受体状态\", \"年龄\", \"特殊病人特征\", \"读写能力\", \"性别\", \"教育情况\", \"居住情况\", \"种族\", \"知情同意\", \"参与其它试验\", \"研究者决定\", \"能力\", \"伦理审查\", \"依存性\", \"成瘾行为\", \"睡眠\", \"锻炼\", \"饮食\", \"酒精使用\", \"性取向\", \"吸烟状况\", \"献血\", \"病例来源\", \"残疾群体\", \"健康群体\", \"数据可及性\"]"],

    ["Using clinical documentation written in Chinese", 
     "Acceptable entries for \"label\" are [\"疾病\", \"症状-患者感受\", \"体征-医生检测\", \"怀孕相关\", \"肿瘤进展\", \"疾病分期\", \"过敏耐受\", \"器官组织状态\", \"预期寿命\", \"口腔相关\", \"药物\", \"治疗或手术\", \"设备\", \"护理\", \"诊断\", \"实验室检查\", \"风险评估\", \"受体状态\", \"年龄\", \"特殊病人特征\", \"读写能力\", \"性别\", \"教育情况\", \"居住情况\", \"种族\", \"知情同意\", \"参与其它试验\", \"研究者决定\", \"能力\", \"伦理审查\", \"依存性\", \"成瘾行为\", \"睡眠\", \"锻炼\", \"饮食\", \"酒精使用\", \"性取向\", \"吸烟状况\", \"献血\", \"病例来源\", \"残疾群体\", \"健康群体\", \"数据可及性\"]"],

    ["From the patient’s clinical record in Chinese", 
     "The \"label\" must be one of [\"疾病\", \"症状-患者感受\", \"体征-医生检测\", \"怀孕相关\", \"肿瘤进展\", \"疾病分期\", \"过敏耐受\", \"器官组织状态\", \"预期寿命\", \"口腔相关\", \"药物\", \"治疗或手术\", \"设备\", \"护理\", \"诊断\", \"实验室检查\", \"风险评估\", \"受体状态\", \"年龄\", \"特殊病人特征\", \"读写能力\", \"性别\", \"教育情况\", \"居住情况\", \"种族\", \"知情同意\", \"参与其它试验\", \"研究者决定\", \"能力\", \"伦理审查\", \"依存性\", \"成瘾行为\", \"睡眠\", \"锻炼\", \"饮食\", \"酒精使用\", \"性取向\", \"吸烟状况\", \"献血\", \"病例来源\", \"残疾群体\", \"健康群体\", \"数据可及性\"]"]
    ],


    55: [
    ["Based on the medical consultation in Chinese", 
     "Valid response options for \"status\" are [\"阳性\", \"阴性\", \"其他\", \"不标注\"]"],

    ["Given the Chinese medical consultation", 
     "The possible values for \"status\" include [\"阳性\", \"阴性\", \"其他\", \"不标注\"]"],

    ["Using the clinical consultation text in Chinese", 
     "Acceptable entries for \"status\" are [\"阳性\", \"阴性\", \"其他\", \"不标注\"]"],

    ["From the Chinese-language medical consultation", 
     "The \"status\" must be one of [\"阳性\", \"阴性\", \"其他\", \"不标注\"]"]
    ],


    56: [
    ["Based on the medical consultation in Chinese", ""],
    ["Given the Chinese medical consultation", ""],
    ["Using the clinical consultation text written in Chinese", ""],
    ["From the Chinese-language medical consultation", ""]
    ],


    57: [
    ["Based on the medical consultation in Chinese,", 
     "Valid response options for \"status\" are [\"positive\", \"negative\", \"uncertain\"]"],

    ["Given the Chinese medical consultation,", 
     "The possible values for \"status\" include [\"positive\", \"negative\", \"uncertain\"]"],

    ["Using the clinical consultation text written in Chinese,", 
     "Acceptable entries for \"status\" are [\"positive\", \"negative\", \"uncertain\"]"],

    ["From the Chinese-language medical consultation,", 
     "The \"status\" must be one of [\"positive\", \"negative\", \"uncertain\"]"]
    ],


    58: [
    ["Based on the medical consultation in Chinese", ""],
    ["Given the Chinese medical consultation", ""],
    ["Using the clinical consultation text in Chinese", ""],
    ["From the Chinese-language medical consultation", ""],
    ],
    
    59: [
    ["Based on the utterance from a medical consultation in Chinese", 
     "Valid response options for \"label\" are [\"提问-症状\", \"提问-病因\", \"提问-基本信息\", \"提问-已有检查和治疗\", \"告知-用药建议\", \"告知-就医建议\", \"告知-注意事项\", \"诊断\", \"告知-症状\", \"告知-病因\", \"告知-基本信息\", \"告知-已有检查和治疗\", \"提问-用药建议\", \"提问-就医建议\", \"提问-注意事项\"]"],

    ["Given the utterance in a Chinese medical consultation", 
     "The possible values for \"label\" include [\"提问-症状\", \"提问-病因\", \"提问-基本信息\", \"提问-已有检查和治疗\", \"告知-用药建议\", \"告知-就医建议\", \"告知-注意事项\", \"诊断\", \"告知-症状\", \"告知-病因\", \"告知-基本信息\", \"告知-已有检查和治疗\", \"提问-用药建议\", \"提问-就医建议\", \"提问-注意事项\"]"],

    ["Using a single utterance from a medical consultation in Chinese", 
     "Acceptable entries for \"label\" are [\"提问-症状\", \"提问-病因\", \"提问-基本信息\", \"提问-已有检查和治疗\", \"告知-用药建议\", \"告知-就医建议\", \"告知-注意事项\", \"诊断\", \"告知-症状\", \"告知-病因\", \"告知-基本信息\", \"告知-已有检查和治疗\", \"提问-用药建议\", \"提问-就医建议\", \"提问-注意事项\"]"],

    ["From the Chinese-language medical consultation utterance", 
     "The \"label\" must be one of [\"提问-症状\", \"提问-病因\", \"提问-基本信息\", \"提问-已有检查和治疗\", \"告知-用药建议\", \"告知-就医建议\", \"告知-注意事项\", \"诊断\", \"告知-症状\", \"告知-病因\", \"告知-基本信息\", \"告知-已有检查和治疗\", \"提问-用药建议\", \"提问-就医建议\", \"提问-注意事项\"]"]
    ],


    60: [
    ["Based on the clinical document of a patient.", 
     "Valid response options for \"category_1\" are [\"mention\", \"high A1c\", \"high glucose\"].\nValid response options for \"category_2\" are [\"before DCT\", \"during DCT\", \"after DCT\"]"],

    ["Given a patient's clinical document.", 
     "The possible values for \"category_1\" include [\"mention\", \"high A1c\", \"high glucose\"].\nThe possible values for \"category_2\" include [\"before DCT\", \"during DCT\", \"after DCT\"]"],

    ["Using the clinical documentation of a patient.", 
     "Acceptable entries for \"category_1\" are [\"mention\", \"high A1c\", \"high glucose\"].\nAcceptable entries for \"category_2\" are [\"before DCT\", \"during DCT\", \"after DCT\"]"],

    ["From the clinical record of a patient.", 
     "The \"category_1\" must be one of [\"mention\", \"high A1c\", \"high glucose\"].\nThe \"category_2\" must be one of [\"before DCT\", \"during DCT\", \"after DCT\"]"]
    ],

    61: [
    ["Based on the clinical document of a patient", 
     "Valid response options for \"category_1\" are [\"mention\", \"event\", \"test\", \"symptom\"].\nValid response options for \"category_2\" are [\"before DCT\", \"during DCT\", \"after DCT\"]"],

    ["Given a patient's clinical document", 
     "The possible values for \"category_1\" include [\"mention\", \"event\", \"test\", \"symptom\"].\nThe possible values for \"category_2\" include [\"before DCT\", \"during DCT\", \"after DCT\"]"],

    ["Using the clinical documentation of a patient", 
     "Acceptable entries for \"category_1\" are [\"mention\", \"event\", \"test\", \"symptom\"].\nAcceptable entries for \"category_2\" are [\"before DCT\", \"during DCT\", \"after DCT\"]"],

    ["From the clinical record of a patient", 
     "The \"category_1\" must be one of [\"mention\", \"event\", \"test\", \"symptom\"].\nThe \"category_2\" must be one of [\"before DCT\", \"during DCT\", \"after DCT\"]"]
    ],


    62: [
    ["Based on the clinical document of a patient", 
     "Valid response options for \"category_1\" are [\"mention\", \"high cholesterol\", \"high LDL\"].\nValid response options for \"category_2\" are [\"before DCT\", \"during DCT\", \"after DCT\"]"],

    ["Given a patient's clinical document", 
     "The possible values for \"category_1\" include [\"mention\", \"high cholesterol\", \"high LDL\"].\nThe possible values for \"category_2\" include [\"before DCT\", \"during DCT\", \"after DCT\"]"],

    ["Using the clinical documentation of a patient", 
     "Acceptable entries for \"category_1\" are [\"mention\", \"high cholesterol\", \"high LDL\"].\nAcceptable entries for \"category_2\" are [\"before DCT\", \"during DCT\", \"after DCT\"]"],

    ["From the clinical record of a patient", 
     "The \"category_1\" must be one of [\"mention\", \"high cholesterol\", \"high LDL\"].\nThe \"category_2\" must be one of [\"before DCT\", \"during DCT\", \"after DCT\"]"]
    ],

    63: [
    ["Based on the clinical document of a patient.", 
     "Valid response options for \"category_1\" are [\"mention\", \"high blood pressure\"].\nValid response options for \"category_2\" are [\"before DCT\", \"during DCT\", \"after DCT\"]"],

    ["Given a patient's clinical document.", 
     "The possible values for \"category_1\" include [\"mention\", \"high blood pressure\"].\nThe possible values for \"category_2\" include [\"before DCT\", \"during DCT\", \"after DCT\"]"],

    ["Using the clinical documentation of a patient.", 
     "Acceptable entries for \"category_1\" are [\"mention\", \"high blood pressure\"].\nAcceptable entries for \"category_2\" are [\"before DCT\", \"during DCT\", \"after DCT\"]"],

    ["From the clinical record of a patient.", 
     "The \"category_1\" must be one of [\"mention\", \"high blood pressure\"].\nThe \"category_2\" must be one of [\"before DCT\", \"during DCT\", \"after DCT\"]"]
    ],

    64: [
    ["Based on the clinical document of a patient", 
     "Valid response options for \"category\" are [\"before DCT\", \"during DCT\", \"after DCT\"]"],

    ["Given a patient's clinical document", 
     "The possible values for \"category\" include [\"before DCT\", \"during DCT\", \"after DCT\"]"],

    ["Using the clinical documentation of a patient", 
     "Acceptable entries for \"category\" are [\"before DCT\", \"during DCT\", \"after DCT\"]"],

    ["From the clinical record of a patient", 
     "The \"category\" must be one of [\"before DCT\", \"during DCT\", \"after DCT\"]"]
    ],

    65: [
    ["Based on the clinical case report in French", 
     "Valid response options for \"genre\" are [\"féminin\", \"masculin\", \"None\"].\nValid response options for \"issue\" are [\"guérison\", \"amélioration\", \"stable\", \"détérioration\", \"décès\", \"None\"]"],

    ["Given a French clinical case report", 
     "The possible values for \"genre\" include [\"féminin\", \"masculin\", \"None\"].\nThe possible values for \"issue\" include [\"guérison\", \"amélioration\", \"stable\", \"détérioration\", \"décès\", \"None\"]"],

    ["Using the clinical case report written in French", 
     "Acceptable entries for \"genre\" are [\"féminin\", \"masculin\", \"None\"].\nAcceptable entries for \"issue\" are [\"guérison\", \"amélioration\", \"stable\", \"détérioration\", \"décès\", \"None\"]"],

    ["From the French-language clinical case report", 
     "The \"genre\" must be one of [\"féminin\", \"masculin\", \"None\"].\nThe \"issue\" must be one of [\"guérison\", \"amélioration\", \"stable\", \"détérioration\", \"décès\", \"None\"]"]
    ],
    
    66: [
    ["Based on the clinical care report in French", 
     "Valid response options for evidence include: for \"genre\", a word or short phrase indicating the person's gender; for \"origine\" and \"issue\", a sentence or short paragraph describing the person's origin and outcome, respectively. If not mentioned, return \"None\"."],

    ["Given a French clinical care report", 
     "The possible values for evidence are: for \"genre\", a word or brief phrase that signals the gender; for \"origine\" and \"issue\", a sentence or short paragraph pointing to the origin and outcome. If unavailable, return \"None\"."],

    ["Using the clinical care report written in French", 
     "Acceptable entries for evidence: \"genre\" should be indicated by a word or short phrase; \"origine\" and \"issue\" by a sentence or paragraph. Use \"None\" if no evidence is present."],

    ["From the French-language clinical care report", 
     "The \"genre\" must be supported by a word or short phrase; the \"origine\" and \"issue\" must be supported by a sentence or short paragraph. If any are not mentioned, return \"None\"."]
    ],

    67: [
    ["Based on the premise-hypothesis statements pair labeled as \"Premise statement\" and \"Hypothesis statement\" in Russian", 
     "Valid response options for \"label\" are [\"entailment\", \"contradiction\", \"neutral\"]"],

    ["Given the Russian statement pair labeled \"Premise statement\" and \"Hypothesis statement\"", 
     "The possible values for \"label\" include [\"entailment\", \"contradiction\", \"neutral\"]"],

    ["Using the premise and hypothesis labeled as \"Premise statement\" and \"Hypothesis statement\" in Russian", 
     "Acceptable entries for \"label\" are [\"entailment\", \"contradiction\", \"neutral\"]"],

    ["From the pair of Russian-language statements labeled \"Premise statement\" and \"Hypothesis statement\"", 
     "The \"label\" must be one of [\"entailment\", \"contradiction\", \"neutral\"]"]
    ],

    68: [
    ["Based on the clinical text of a patient in Russian", 
     "Valid response options for \"type\" are [\"Adverse Drug Reaction\", \"Drugclass\", \"Finding\", \"Drugform\", \"Drugname\", \"Drug Interaction\"]"],

    ["Given a patient's clinical documentation in Russian", 
     "The possible values for \"type\" include [\"Adverse Drug Reaction\", \"Drugclass\", \"Finding\", \"Drugform\", \"Drugname\", \"Drug Interaction\"]"],

    ["Using the Russian-language clinical text of a patient", 
     "Acceptable entries for \"type\" are [\"Adverse Drug Reaction\", \"Drugclass\", \"Finding\", \"Drugform\", \"Drugname\", \"Drug Interaction\"]"],

    ["From the clinical notes in Russian for a patient", 
     "The \"type\" must be one of [\"Adverse Drug Reaction\", \"Drugclass\", \"Finding\", \"Drugform\", \"Drugname\", \"Drug Interaction\"]"]
    ],

    69: [
    ["Based on the clinical text of a patient in Norwegian", 
     "Valid response options for \"type\" are [\"First_Name\", \"Last_Name\", \"Age\", \"Health_Care_Unit\", \"Social_Security_Number\", \"Phone_Number\", \"Date_Full\", \"Date_Part\", \"Location\"]"],

    ["Given a patient's clinical documentation in Norwegian", 
     "The possible values for \"type\" include [\"First_Name\", \"Last_Name\", \"Age\", \"Health_Care_Unit\", \"Social_Security_Number\", \"Phone_Number\", \"Date_Full\", \"Date_Part\", \"Location\"]"],

    ["Using the Norwegian-language clinical text of a patient", 
     "Acceptable entries for \"type\" are [\"First_Name\", \"Last_Name\", \"Age\", \"Health_Care_Unit\", \"Social_Security_Number\", \"Phone_Number\", \"Date_Full\", \"Date_Part\", \"Location\"]"],

    ["From the clinical notes in Norwegian for a patient", 
     "The \"type\" must be one of [\"First_Name\", \"Last_Name\", \"Age\", \"Health_Care_Unit\", \"Social_Security_Number\", \"Phone_Number\", \"Date_Full\", \"Date_Part\", \"Location\"]"]
    ],

    70: [
    ["Based on the clinical text of a patient in Russian", 
     "Valid response options for \"type\" are [\"Disease\", \"Symptom\", \"Drug\", \"Treatment\", \"Body location\", \"Severity\", \"Course\"]"],

    ["Given a patient's clinical documentation in Russian", 
     "The possible values for \"type\" include [\"Disease\", \"Symptom\", \"Drug\", \"Treatment\", \"Body location\", \"Severity\", \"Course\"]"],

    ["Using the Russian-language clinical text of a patient", 
     "Acceptable entries for \"type\" are [\"Disease\", \"Symptom\", \"Drug\", \"Treatment\", \"Body location\", \"Severity\", \"Course\"]"],

    ["From the clinical notes in Russian for a patient", 
     "The \"type\" must be one of [\"Disease\", \"Symptom\", \"Drug\", \"Treatment\", \"Body location\", \"Severity\", \"Course\"]"]
    ],

    71: [
    ["Based on the following two clinical sentences labeled as \"Sentence A\" and \"Sentence B\" in French", 
     "Valid response options for \"score\" are [\"0\", \"1\", \"2\", \"3\", \"4\", \"5\"]"],

    ["Given the pair of clinical sentences in French labeled \"Sentence A\" and \"Sentence B\"", 
     "The possible values for \"score\" include [\"0\", \"1\", \"2\", \"3\", \"4\", \"5\"]"],

    ["Using the two French clinical sentences identified as \"Sentence A\" and \"Sentence B\"", 
     "Acceptable entries for \"score\" are [\"0\", \"1\", \"2\", \"3\", \"4\", \"5\"]"],

    ["From the French-language clinical sentence pair labeled \"Sentence A\" and \"Sentence B\"", 
     "The \"score\" must be one of [\"0\", \"1\", \"2\", \"3\", \"4\", \"5\"]"]
    ],


    72: [
    ["Based on the following sentence from a discharge summary of a cancer patient (hepatocellular carcinoma or melanoma) in German", 
     "Valid response options for \"type\" are [\"diagnosis\", \"treatment\", \"medication\"].\nValid response options for \"status\" are [\"right\", \"left\", \"both\", \"negation\", \"speculation\", \"possible future\"]"],

    ["Given a sentence from the discharge summary of a German-speaking cancer patient (hepatocellular carcinoma or melanoma)", 
     "The possible values for \"type\" include [\"diagnosis\", \"treatment\", \"medication\"].\nThe possible values for \"status\" include [\"right\", \"left\", \"both\", \"negation\", \"speculation\", \"possible future\"]"],

    ["Using the sentence from a discharge summary of a patient with hepatocellular carcinoma or melanoma in German", 
     "Acceptable entries for \"type\" are [\"diagnosis\", \"treatment\", \"medication\"].\nAcceptable entries for \"status\" are [\"right\", \"left\", \"both\", \"negation\", \"speculation\", \"possible future\"]"],

    ["From the discharge summary sentence of a German cancer patient (hepatocellular carcinoma or melanoma)", 
     "The \"type\" must be one of [\"diagnosis\", \"treatment\", \"medication\"].\nThe \"status\" must be one of [\"right\", \"left\", \"both\", \"negation\", \"speculation\", \"possible future\"]"]
    ],

    73: [
    ["Based on the following clinical document related to the cardiovascular domain in German", 
     "Valid response options for \"type\" are [\"ACTIVEING\", \"DRUG\", \"DURATION\", \"FORM\", \"FREQUENCY\", \"STRENGTH\"]"],

    ["Given a clinical document in German concerning the cardiovascular domain", 
     "The possible values for \"type\" include [\"ACTIVEING\", \"DRUG\", \"DURATION\", \"FORM\", \"FREQUENCY\", \"STRENGTH\"]"],

    ["Using the German clinical document related to cardiovascular care", 
     "Acceptable entries for \"type\" are [\"ACTIVEING\", \"DRUG\", \"DURATION\", \"FORM\", \"FREQUENCY\", \"STRENGTH\"]"],

    ["From the cardiovascular-related clinical document written in German", 
     "The \"type\" must be one of [\"ACTIVEING\", \"DRUG\", \"DURATION\", \"FORM\", \"FREQUENCY\", \"STRENGTH\"]"]
    ],
    
    74: [
    ["Based on the clinical summaries of a patient in German", 
     "Valid response options for \"type\" are [\"LOCATION_COUNTRY\", \"NAME_DOCTOR\", \"AGE\", \"CONTACT_FAX\", \"LOCATION_ZIP\", \"LOCATION_ORGANIZATION\", \"CONTACT_PHONE\", \"DATE\", \"LOCATION_CITY\", \"CONTACT_EMAIL\", \"NAME_PATIENT\", \"LOCATION_HOSPITAL\", \"PROFESSION\", \"NAME_TITLE\", \"NAME_USERNAME\", \"ID\", \"NAME_RELATIVE\", \"NAME_EXT\", \"LOCATION_STREET\"]"],

    ["Given the patient's clinical summaries written in German", 
     "The possible values for \"type\" include [\"LOCATION_COUNTRY\", \"NAME_DOCTOR\", \"AGE\", \"CONTACT_FAX\", \"LOCATION_ZIP\", \"LOCATION_ORGANIZATION\", \"CONTACT_PHONE\", \"DATE\", \"LOCATION_CITY\", \"CONTACT_EMAIL\", \"NAME_PATIENT\", \"LOCATION_HOSPITAL\", \"PROFESSION\", \"NAME_TITLE\", \"NAME_USERNAME\", \"ID\", \"NAME_RELATIVE\", \"NAME_EXT\", \"LOCATION_STREET\"]"],

    ["Using the clinical summaries in German for a patient", 
     "Acceptable entries for \"type\" are [\"LOCATION_COUNTRY\", \"NAME_DOCTOR\", \"AGE\", \"CONTACT_FAX\", \"LOCATION_ZIP\", \"LOCATION_ORGANIZATION\", \"CONTACT_PHONE\", \"DATE\", \"LOCATION_CITY\", \"CONTACT_EMAIL\", \"NAME_PATIENT\", \"LOCATION_HOSPITAL\", \"PROFESSION\", \"NAME_TITLE\", \"NAME_USERNAME\", \"ID\", \"NAME_RELATIVE\", \"NAME_EXT\", \"LOCATION_STREET\"]"],

    ["From the German-language clinical summaries of a patient", 
     "The \"type\" must be one of [\"LOCATION_COUNTRY\", \"NAME_DOCTOR\", \"AGE\", \"CONTACT_FAX\", \"LOCATION_ZIP\", \"LOCATION_ORGANIZATION\", \"CONTACT_PHONE\", \"DATE\", \"LOCATION_CITY\", \"CONTACT_EMAIL\", \"NAME_PATIENT\", \"LOCATION_HOSPITAL\", \"PROFESSION\", \"NAME_TITLE\", \"NAME_USERNAME\", \"ID\", \"NAME_RELATIVE\", \"NAME_EXT\", \"LOCATION_STREET\"]"]
    ],

    75: [
    ["Based on the medical incident report in Japanese", 
     "Valid response options for \"type\" are [\"Wrong Drug\", \"Wrong Form\", \"Wrong Mode\", \"Wrong Strength amount\", \"Wrong Strength rate\", \"Wrong Strength concentration\", \"Wrong Timing\", \"Wrong Date\", \"Wrong Duration\", \"Wrong Frequency\", \"Wrong Dosage\", \"Wrong Route\", \"Others\"]"],

    ["Given the Japanese medical incident report", 
     "The possible values for \"type\" include [\"Wrong Drug\", \"Wrong Form\", \"Wrong Mode\", \"Wrong Strength amount\", \"Wrong Strength rate\", \"Wrong Strength concentration\", \"Wrong Timing\", \"Wrong Date\", \"Wrong Duration\", \"Wrong Frequency\", \"Wrong Dosage\", \"Wrong Route\", \"Others\"]"],

    ["Using the medical incident documentation in Japanese", 
     "Acceptable entries for \"type\" are [\"Wrong Drug\", \"Wrong Form\", \"Wrong Mode\", \"Wrong Strength amount\", \"Wrong Strength rate\", \"Wrong Strength concentration\", \"Wrong Timing\", \"Wrong Date\", \"Wrong Duration\", \"Wrong Frequency\", \"Wrong Dosage\", \"Wrong Route\", \"Others\"]"],

    ["From the incident report written in Japanese", 
     "The \"type\" must be one of [\"Wrong Drug\", \"Wrong Form\", \"Wrong Mode\", \"Wrong Strength amount\", \"Wrong Strength rate\", \"Wrong Strength concentration\", \"Wrong Timing\", \"Wrong Date\", \"Wrong Duration\", \"Wrong Frequency\", \"Wrong Dosage\", \"Wrong Route\", \"Others\"]"]
    ],


    76: [
    ["Based on the following medical incident report in Japanese", 
     "Valid response options for \"type\" are [\"Strength concentration\", \"Frequency\", \"Date\", \"Drug\", \"Dosage\", \"Strength rate\", \"Drug form\", \"Duration\", \"Strength amount\", \"Drug mode\", \"Route\", \"Timing\"].\nValid response options for \"intention\" are [\"IA\", \"IN\", \"NA\"]"],

    ["Given the Japanese medical incident report", 
     "The possible values for \"type\" include [\"Strength concentration\", \"Frequency\", \"Date\", \"Drug\", \"Dosage\", \"Strength rate\", \"Drug form\", \"Duration\", \"Strength amount\", \"Drug mode\", \"Route\", \"Timing\"].\nThe possible values for \"intention\" include [\"IA\", \"IN\", \"NA\"]"],

    ["Using the medical incident report written in Japanese", 
     "Acceptable entries for \"type\" are [\"Strength concentration\", \"Frequency\", \"Date\", \"Drug\", \"Dosage\", \"Strength rate\", \"Drug form\", \"Duration\", \"Strength amount\", \"Drug mode\", \"Route\", \"Timing\"].\nAcceptable entries for \"intention\" are [\"IA\", \"IN\", \"NA\"]"],

    ["From the Japanese-language medical incident report", 
     "The \"type\" must be one of [\"Strength concentration\", \"Frequency\", \"Date\", \"Drug\", \"Dosage\", \"Strength rate\", \"Drug form\", \"Duration\", \"Strength amount\", \"Drug mode\", \"Route\", \"Timing\"].\nThe \"intention\" must be one of [\"IA\", \"IN\", \"NA\"]"]
    ],

    77: [
    ["Based on the following medical incident report in Japanese", 
     "Valid response options for \"type\" are [\"Strength concentration\", \"Frequency\", \"Date\", \"Drug\", \"Dosage\", \"Strength rate\", \"Drug form\", \"Duration\", \"Strength amount\", \"Drug mode\", \"Route\", \"Timing\"]"],

    ["Given the Japanese medical incident report", 
     "The possible values for \"type\" include [\"Strength concentration\", \"Frequency\", \"Date\", \"Drug\", \"Dosage\", \"Strength rate\", \"Drug form\", \"Duration\", \"Strength amount\", \"Drug mode\", \"Route\", \"Timing\"]"],

    ["Using the medical incident report written in Japanese", 
     "Acceptable entries for \"type\" are [\"Strength concentration\", \"Frequency\", \"Date\", \"Drug\", \"Dosage\", \"Strength rate\", \"Drug form\", \"Duration\", \"Strength amount\", \"Drug mode\", \"Route\", \"Timing\"]"],

    ["From the Japanese-language medical incident report", 
     "The \"type\" must be one of [\"Strength concentration\", \"Frequency\", \"Date\", \"Drug\", \"Dosage\", \"Strength rate\", \"Drug form\", \"Duration\", \"Strength amount\", \"Drug mode\", \"Route\", \"Timing\"]"]
    ],

    78: [
    ["Based on the clinical report of a patient in Japanese", 
     "Valid response options for \"type\" are [\"age\", \"sex\", \"smoking\", \"drinking\", \"state\", \"body\", \"tissue\", \"item\", \"clinical test\", \"PN\", \"judge\", \"quantity evaluation\", \"quantity progress\", \"quality evaluation\", \"quality progress\", \"value\", \"unit\", \"time\", \"time span\"]"],

    ["Given a patient's clinical report written in Japanese", 
     "The possible values for \"type\" include [\"age\", \"sex\", \"smoking\", \"drinking\", \"state\", \"body\", \"tissue\", \"item\", \"clinical test\", \"PN\", \"judge\", \"quantity evaluation\", \"quantity progress\", \"quality evaluation\", \"quality progress\", \"value\", \"unit\", \"time\", \"time span\"]"],

    ["Using the Japanese-language clinical report of a patient", 
     "Acceptable entries for \"type\" are [\"age\", \"sex\", \"smoking\", \"drinking\", \"state\", \"body\", \"tissue\", \"item\", \"clinical test\", \"PN\", \"judge\", \"quantity evaluation\", \"quantity progress\", \"quality evaluation\", \"quality progress\", \"value\", \"unit\", \"time\", \"time span\"]"],

    ["From the clinical documentation in Japanese for a patient", 
     "The \"type\" must be one of [\"age\", \"sex\", \"smoking\", \"drinking\", \"state\", \"body\", \"tissue\", \"item\", \"clinical test\", \"PN\", \"judge\", \"quantity evaluation\", \"quantity progress\", \"quality evaluation\", \"quality progress\", \"value\", \"unit\", \"time\", \"time span\"]"]
    ],

    79: [
    ["Based on the following question from a patient", ""],
    ["Given a patient's question", ""],
    ["Using the question provided by the patient", ""],
    ["From the patient's stated question", ""]
    ],

    80: [
    ["Based on the following question from a patient", ""],
    ["Given the following patient question", ""],
    ["Using the question asked by the patient", ""],
    ["From the patient's provided question", ""]
    ],

    81: [
    ["Based on the history of present illness, physical examination, and radiology reports of a patient with acute abdominal pain", 
     "Valid response options for \"disease\" are [\"Appendicitis\", \"Cholecystitis\", \"Diverticulitis\", \"Pancreatitis\"]"],

    ["Given the clinical history, physical exam reports, and radiology results of a patient with acute abdominal pain", 
     "The possible values for \"disease\" include [\"Appendicitis\", \"Cholecystitis\", \"Diverticulitis\", \"Pancreatitis\"]"],

    ["Using the present illness narrative, physical examination, and imaging reports of a patient experiencing acute abdominal pain", 
     "Acceptable entries for \"disease\" are [\"Appendicitis\", \"Cholecystitis\", \"Diverticulitis\", \"Pancreatitis\"]"],

    ["From the history of present illness, exam notes, and radiological results of a patient with acute abdominal pain", 
     "The \"disease\" must be one of [\"Appendicitis\", \"Cholecystitis\", \"Diverticulitis\", \"Pancreatitis\"]"]
    ],

    82: [
    ["Based on a patient's basic information and admission notes", 
     "Valid response options for \"label\" are [\"A\", \"B\", \"C\", \"D\"]"],

    ["Given the patient's basic details and admission documentation", 
     "The possible values for \"label\" include [\"A\", \"B\", \"C\", \"D\"]"],

    ["Using the basic demographic and admission notes of a patient", 
     "Acceptable entries for \"label\" are [\"A\", \"B\", \"C\", \"D\"]"],

    ["From the admission note and basic information of a patient", 
     "The \"label\" must be one of [\"A\", \"B\", \"C\", \"D\"]"]
    ],

    83: [
    ["Based on a patient's basic information and admission notes", 
     "Valid response options for \"label\" are [\"Yes\", \"No\"]"],

    ["Given the patient's basic details and admission documentation", 
     "The possible values for \"label\" include [\"Yes\", \"No\"]"],

    ["Using the basic demographic and admission notes of a patient", 
     "Acceptable entries for \"label\" are [\"Yes\", \"No\"]"],

    ["From the admission note and basic information of a patient", 
     "The \"label\" must be one of [\"Yes\", \"No\"]"]
    ],

    84: [
    ["Based on the patient's clinical notes from electronic health records", ""],
    ["Given the clinical documentation from the patient's electronic health records (EHR)", ""],
    ["Using the electronic health record clinical notes of the patient", ""],
    ["From the patient's electronic health records (EHR) clinical notes", ""]
    ],

    85: [
    ["Based on a patient's clinical notes from electronic health records (EHR)", 
     "Valid response options for \"disease\" are [\"Acute Coronary Syndrome\", \"Heart Failure\", \"Gastro-oesophageal Reflux Disease\", \"Pulmonary Embolism\", \"Hypertension\", \"Peptic Ulcer Disease\", \"Stroke\", \"Gastritis\", \"Multiple Sclerosis\", \"Adrenal Insufficiency\", \"Pneumonia\", \"Chronic Obstructive Pulmonary Disease\", \"Aortic Dissection\", \"Asthma\", \"Diabetes\", \"Pituitary Disease\", \"Alzheimer\", \"Atrial Fibrillation\", \"Thyroid Disease\", \"Cardiomyopathy\", \"Epilepsy\", \"Upper Gastrointestinal Bleeding\", \"Tuberculosis\", \"Migraine\", \"Hyperlipidemia\"]"],

    ["Given clinical notes for a patient from electronic health records (EHR)", 
     "The possible values for \"disease\" include [\"Acute Coronary Syndrome\", \"Heart Failure\", \"Gastro-oesophageal Reflux Disease\", \"Pulmonary Embolism\", \"Hypertension\", \"Peptic Ulcer Disease\", \"Stroke\", \"Gastritis\", \"Multiple Sclerosis\", \"Adrenal Insufficiency\", \"Pneumonia\", \"Chronic Obstructive Pulmonary Disease\", \"Aortic Dissection\", \"Asthma\", \"Diabetes\", \"Pituitary Disease\", \"Alzheimer\", \"Atrial Fibrillation\", \"Thyroid Disease\", \"Cardiomyopathy\", \"Epilepsy\", \"Upper Gastrointestinal Bleeding\", \"Tuberculosis\", \"Migraine\", \"Hyperlipidemia\"]"],

    ["Using the patient's clinical notes extracted from electronic health records (EHR)", 
     "Acceptable entries for \"disease\" are [\"Acute Coronary Syndrome\", \"Heart Failure\", \"Gastro-oesophageal Reflux Disease\", \"Pulmonary Embolism\", \"Hypertension\", \"Peptic Ulcer Disease\", \"Stroke\", \"Gastritis\", \"Multiple Sclerosis\", \"Adrenal Insufficiency\", \"Pneumonia\", \"Chronic Obstructive Pulmonary Disease\", \"Aortic Dissection\", \"Asthma\", \"Diabetes\", \"Pituitary Disease\", \"Alzheimer\", \"Atrial Fibrillation\", \"Thyroid Disease\", \"Cardiomyopathy\", \"Epilepsy\", \"Upper Gastrointestinal Bleeding\", \"Tuberculosis\", \"Migraine\", \"Hyperlipidemia\"]"],

    ["From the electronic health records (EHR) containing the patient's clinical notes", 
     "The \"disease\" must be one of [\"Acute Coronary Syndrome\", \"Heart Failure\", \"Gastro-oesophageal Reflux Disease\", \"Pulmonary Embolism\", \"Hypertension\", \"Peptic Ulcer Disease\", \"Stroke\", \"Gastritis\", \"Multiple Sclerosis\", \"Adrenal Insufficiency\", \"Pneumonia\", \"Chronic Obstructive Pulmonary Disease\", \"Aortic Dissection\", \"Asthma\", \"Diabetes\", \"Pituitary Disease\", \"Alzheimer\", \"Atrial Fibrillation\", \"Thyroid Disease\", \"Cardiomyopathy\", \"Epilepsy\", \"Upper Gastrointestinal Bleeding\", \"Tuberculosis\", \"Migraine\", \"Hyperlipidemia\"]"]
    ],

    86: [
    ["Based on a patient's clinical notes from electronic health records (EHR)", 
     "Valid response options for \"disease\" are [\"Heart Failure\", \"Gastro-oesophageal Reflux Disease\", \"Hypertension\", \"Non-ST-Elevation Myocardial Infarction\", \"Relapsing-Remitting Multiple Sclerosis\", \"Unstable Angin\", \"Low-risk Pulmonary Embolism\", \"Gastric Ulcers\", \"Chronic Obstructive Pulmonary Disease\", \"Bacterial Pneumonia\", \"ST-Elevation Myocardial Infarction\", \"Hemorrhagic Stroke\", \"Acute Gastritis\", \"Ischemic Stroke\", \"Submassive Pulmonary Embolism\", \"Pituitary Macroadenoma\", \"Secondary Adrenal Insufficiency\", \"Alzheimer\", \"Type B Aortic Dissection\", \"Duodenal Ulcers\", \"Chronic Atrophic Gastritis\", \"Paroxysmal Atrial Fibrillation\", \"Primary Adrenal Insufficiency\", \"Upper Gastrointestinal Bleeding\", \"Type I Diabetes\", \"Type II Diabetes\", \"Chronic Non-atrophic Gastritis\", \"Type A Aortic Dissection\", \"Non-epileptic Seizure\", \"Tuberculosis\", \"Viral Pneumonia\", \"Severe Asthma Exacerbation\", \"Hyperthyroidism\", \"Dilated Cardiomyopathy\", \"Congenital Adrenal Hyperplasia\", \"Epilepsy\", \"Non-Allergic Asthma\", \"Migraine With Aura\", \"Secondary Progressive Multiple Sclerosis\", \"Hypothyroidism\", \"Massive Pulmonary Embolism\", \"Hyperlipidemia\", \"Restrictive Cardiomyopathy\", \"Asthma\", \"COPD Asthma\", \"Hypertrophic Cardiomyopathy\", \"Persistent Atrial Fibrillation\", \"Thyroid Nodules\", \"Primary Progressive Multiple Sclerosis\", \"Allergic Asthma\", \"Cough-Variant Asthma\", \"Arrhythmogenic Right Ventricular Cardiomyopathy\", \"Migraine Without Aura\", \"Thyroiditis\", \"Pituitary Microadenoma\"]"],

    ["Given a patient's clinical documentation from electronic health records (EHR)", 
     "The possible values for \"disease\" include [\"Heart Failure\", \"Gastro-oesophageal Reflux Disease\", \"Hypertension\", \"Non-ST-Elevation Myocardial Infarction\", \"Relapsing-Remitting Multiple Sclerosis\", \"Unstable Angin\", \"Low-risk Pulmonary Embolism\", \"Gastric Ulcers\", \"Chronic Obstructive Pulmonary Disease\", \"Bacterial Pneumonia\", \"ST-Elevation Myocardial Infarction\", \"Hemorrhagic Stroke\", \"Acute Gastritis\", \"Ischemic Stroke\", \"Submassive Pulmonary Embolism\", \"Pituitary Macroadenoma\", \"Secondary Adrenal Insufficiency\", \"Alzheimer\", \"Type B Aortic Dissection\", \"Duodenal Ulcers\", \"Chronic Atrophic Gastritis\", \"Paroxysmal Atrial Fibrillation\", \"Primary Adrenal Insufficiency\", \"Upper Gastrointestinal Bleeding\", \"Type I Diabetes\", \"Type II Diabetes\", \"Chronic Non-atrophic Gastritis\", \"Type A Aortic Dissection\", \"Non-epileptic Seizure\", \"Tuberculosis\", \"Viral Pneumonia\", \"Severe Asthma Exacerbation\", \"Hyperthyroidism\", \"Dilated Cardiomyopathy\", \"Congenital Adrenal Hyperplasia\", \"Epilepsy\", \"Non-Allergic Asthma\", \"Migraine With Aura\", \"Secondary Progressive Multiple Sclerosis\", \"Hypothyroidism\", \"Massive Pulmonary Embolism\", \"Hyperlipidemia\", \"Restrictive Cardiomyopathy\", \"Asthma\", \"COPD Asthma\", \"Hypertrophic Cardiomyopathy\", \"Persistent Atrial Fibrillation\", \"Thyroid Nodules\", \"Primary Progressive Multiple Sclerosis\", \"Allergic Asthma\", \"Cough-Variant Asthma\", \"Arrhythmogenic Right Ventricular Cardiomyopathy\", \"Migraine Without Aura\", \"Thyroiditis\", \"Pituitary Microadenoma\"]"],

    ["Using the clinical notes recorded in the patient’s electronic health records (EHR)", 
     "Acceptable entries for \"disease\" are [\"Heart Failure\", \"Gastro-oesophageal Reflux Disease\", \"Hypertension\", \"Non-ST-Elevation Myocardial Infarction\", \"Relapsing-Remitting Multiple Sclerosis\", \"Unstable Angin\", \"Low-risk Pulmonary Embolism\", \"Gastric Ulcers\", \"Chronic Obstructive Pulmonary Disease\", \"Bacterial Pneumonia\", \"ST-Elevation Myocardial Infarction\", \"Hemorrhagic Stroke\", \"Acute Gastritis\", \"Ischemic Stroke\", \"Submassive Pulmonary Embolism\", \"Pituitary Macroadenoma\", \"Secondary Adrenal Insufficiency\", \"Alzheimer\", \"Type B Aortic Dissection\", \"Duodenal Ulcers\", \"Chronic Atrophic Gastritis\", \"Paroxysmal Atrial Fibrillation\", \"Primary Adrenal Insufficiency\", \"Upper Gastrointestinal Bleeding\", \"Type I Diabetes\", \"Type II Diabetes\", \"Chronic Non-atrophic Gastritis\", \"Type A Aortic Dissection\", \"Non-epileptic Seizure\", \"Tuberculosis\", \"Viral Pneumonia\", \"Severe Asthma Exacerbation\", \"Hyperthyroidism\", \"Dilated Cardiomyopathy\", \"Congenital Adrenal Hyperplasia\", \"Epilepsy\", \"Non-Allergic Asthma\", \"Migraine With Aura\", \"Secondary Progressive Multiple Sclerosis\", \"Hypothyroidism\", \"Massive Pulmonary Embolism\", \"Hyperlipidemia\", \"Restrictive Cardiomyopathy\", \"Asthma\", \"COPD Asthma\", \"Hypertrophic Cardiomyopathy\", \"Persistent Atrial Fibrillation\", \"Thyroid Nodules\", \"Primary Progressive Multiple Sclerosis\", \"Allergic Asthma\", \"Cough-Variant Asthma\", \"Arrhythmogenic Right Ventricular Cardiomyopathy\", \"Migraine Without Aura\", \"Thyroiditis\", \"Pituitary Microadenoma\"]"],

    ["From the patient's electronic health records (EHR) clinical documentation", 
     "The \"disease\" must be one of [\"Heart Failure\", \"Gastro-oesophageal Reflux Disease\", \"Hypertension\", \"Non-ST-Elevation Myocardial Infarction\", \"Relapsing-Remitting Multiple Sclerosis\", \"Unstable Angin\", \"Low-risk Pulmonary Embolism\", \"Gastric Ulcers\", \"Chronic Obstructive Pulmonary Disease\", \"Bacterial Pneumonia\", \"ST-Elevation Myocardial Infarction\", \"Hemorrhagic Stroke\", \"Acute Gastritis\", \"Ischemic Stroke\", \"Submassive Pulmonary Embolism\", \"Pituitary Macroadenoma\", \"Secondary Adrenal Insufficiency\", \"Alzheimer\", \"Type B Aortic Dissection\", \"Duodenal Ulcers\", \"Chronic Atrophic Gastritis\", \"Paroxysmal Atrial Fibrillation\", \"Primary Adrenal Insufficiency\", \"Upper Gastrointestinal Bleeding\", \"Type I Diabetes\", \"Type II Diabetes\", \"Chronic Non-atrophic Gastritis\", \"Type A Aortic Dissection\", \"Non-epileptic Seizure\", \"Tuberculosis\", \"Viral Pneumonia\", \"Severe Asthma Exacerbation\", \"Hyperthyroidism\", \"Dilated Cardiomyopathy\", \"Congenital Adrenal Hyperplasia\", \"Epilepsy\", \"Non-Allergic Asthma\", \"Migraine With Aura\", \"Secondary Progressive Multiple Sclerosis\", \"Hypothyroidism\", \"Massive Pulmonary Embolism\", \"Hyperlipidemia\", \"Restrictive Cardiomyopathy\", \"Asthma\", \"COPD Asthma\", \"Hypertrophic Cardiomyopathy\", \"Persistent Atrial Fibrillation\", \"Thyroid Nodules\", \"Primary Progressive Multiple Sclerosis\", \"Allergic Asthma\", \"Cough-Variant Asthma\", \"Arrhythmogenic Right Ventricular Cardiomyopathy\", \"Migraine Without Aura\", \"Thyroiditis\", \"Pituitary Microadenoma\"]"]
    ]
 }

# %%
direct_templates = [
    "Provide only the final answer in the format below. Do not include any reasoning or explanation.",
    "Output your answer strictly using the following format. Explanations are not allowed.",
    "Respond using the exact format specified. Do not add any additional commentary.",
    "Return the final answer exactly as outlined below without providing any justification or reasoning."
]

cot_templates = [
    "Reason through this task step by step like a clinical expert, then return your final answer in the given format:",
    "Let's use step by step inductive reasoning, given the clinical nature of the task. Return your final answer in the following format:",
    "Determine the answer to the task given the clinical context in a step by step fashion. Give your final answer in the format below:",
    "Let's break the task into multiple steps and reason step by step as a clinician would. Then, provide your final answer in the specified format:"
]

# %%
all_paths = [
    '1-1.ADE-ADE identification.test.SFT.json',
    '1-2.ADE-ADE relation.test.SFT.json',
    '1-3.ADE-Drug dosage.test.SFT.json',
    '3-2.BARR2-resolution.test.SFT.json',
    '5.BrainMRI-AIS.test.SFT.json',
    '6.Brateca.hospitalization.test.SFT.json',
    '6.Brateca.mortality.test.SFT.json',
    '7.Cantemist.CODING.test.SFT.json',
    '7.Cantemist.NER.test.SFT.json',
    '7.Cantemist.Norm.test.SFT.json',
    '8.CARES.area.test.SFT.json',
    '8.CARES.icd10_block.test.SFT.json',
    '8.CARES.icd10_chapter.test.SFT.json',
    '8.CARES.icd10_sub_block.test.SFT.json',
    '9.CHIP-CDEE.test.SFT.json',
    '12.C-EMRS.test.SFT.json',
    '17-1.CLEF_eHealth_2020_CodiEsp_corpus-ICD-10-CM.test.SFT.json',
    '17-2.CLEF_eHealth_2020_CodiEsp_corpus-ICD-10-PCS.test.SFT.json',
    '19.ClinicalNotes-UPMC.test.SFT.json',
    '20.clinical records from the Mexican Social Security Institute.test.SFT.json',
    '21.CLINpt.test.SFT.json',
    '22.CLIP.test.SFT.json',
    '23.cMedQA.test.SFT.json',
    '26.DialMed.test.SFT.json',
    '27.DiSMed.test.SFT.json',
    '28.MIE.test.SFT.json',
    '29.EHRQA.primary_department.test.SFT.json',
    '29.EHRQA.qa.test.SFT.json',
    '29.EHRQA.sub_department.test.SFT.json',
    '31.Ex4CDS.test.SFT.json',
    '33.GOUT-CC.consensus.test.SFT.json',
    '35.n2c2 2006 - De-identification.test.SFT.json',
    '37.i2b2-2009-Medication-Extraction-Challenge.test.SFT.json',
    '38-1.i2b2-2010-Relations-Challenge-concept.test.SFT.json',
    '38-2.i2b2-2010-Relations-Challenge-assertion.test.SFT.json',
    '38-3.i2b2-2010-Relations-Challenge-relation.test.SFT.json',
    '41.n2c2 2014 - De-identification.test.SFT.json',
    '43.IMCS-V2-NER.test.SFT.json',
    '46.Japanese Case Reports.test.SFT.json',
    '48.meddocan.test.SFT.json',
    '51.MEDIQA_2019_Task2_RQE.test.SFT.json',
    '55.MedNLI.test.SFT.json',
    '57.MedSTS.test.SFT.json',
    '62.mtsamples.test.SFT.json',
    '63.MTSamples-temporal annotation.test.SFT.json',
    '65.n2c2-2018-Track2-Adverse-Drug-Events-and-Medication-Extraction.test.SFT.json',
    '66-1.NorSynthClinical-entity.test.SFT.json',
    '66-2.NorSynthClinical-relation.test.SFT.json',
    '68.NUBES.test.SFT.json',
    '76-1.MTS-Dialog-MEDIQA-2023-chat-task-A.test.SFT.json',
    '76-2.MTS-Dialog-MEDIQA-2023-sum-task-A.test.SFT.json',
    '76-3.MTS-Dialog-MEDIQA-2023-sum-task-B.test.SFT.json',
    '80.RuMedDaNet.test.SFT.json',
    '81.CHIP-CDN.test.SFT.json',
    '82.CHIP-CTC.test.SFT.json',
    '83.CHIP-MDCFNPC.test.SFT.json',
    '84.MedDG.test.SFT.json',
    '85.IMCS-V2-SR.test.SFT.json',
    '86.IMCS-V2-MRG.test.SFT.json',
    '87.IMCS-V2-DAC.test.SFT.json',
    '90-1.n2c2 2014 - Heart Disease Challenge - Diabete.test.SFT.json',
    '90-2.n2c2 2014 - Heart Disease Challenge - CAD.test.SFT.json',
    '90-3.n2c2 2014 - Heart Disease Challenge - Hyperlipidemia.test.SFT.json',
    '90-4.n2c2 2014 - Heart Disease Challenge - Hypertension.test.SFT.json',
    '90-8.n2c2 2014 - Heart Disease Challenge - Medication.test.SFT.json',
    '91-1.CAS.label.test.SFT.json',
    '91-2.CAS.evidence.test.SFT.json',
    '93.RuMedNLI.test.SFT.json',
    '94.RuDReC.test.SFT.json',
    '95.NorSynthClinical-PHI.test.SFT.json',
    '96.RuCCoN.NER.test.SFT.json',
    '97.CLISTER.test.SFT.json',
    '98.BRONCO150.NER_status.test.SFT.json',
    '99.CARDIO:DE.test.SFT.json',
    '100.GraSSCo_PHI.test.SFT.json',
    '101.IFMIR.IncidentType.test.SFT.json',
    '101.IFMIR.NER_factuality.test.SFT.json',
    '101.IFMIR.NER.test.SFT.json',
    '102.iCorpus.test.SFT.json',
    '103.icliniq-10k.test.SFT.json',
    '104.HealthCareMagic-100k.test.SFT.json',
    '105.MIMIC-IV CDM.test.SFT.json',
    '106.MIMIC-III Outcome.LoS.test.SFT.json',
    '106.MIMIC-III Outcome.Mortality.test.SFT.json',
    '107.MIMIC-IV BHC.test.SFT.json',
    '108.MIMIC-IV DiReCT.Dis.test.SFT.json',
    '108.MIMIC-IV DiReCT.PDD.test.SFT.json'
]

# %%
# -- CONFIGURATION --
# all_paths: List[str] of your task filenames
# cot_templates:    List[str] of your CoT prompt fragments
# direct_templates: List[str] of your direct‐prompt fragments
# revised_prompts:  List[List[Tuple[str, Optional[str]]]]
#   where revised_prompts[task_idx][template_idx] == (new_prefix, new_optional_list)

output_base = 'updated-datasets-2'

for task_idx, task_name in enumerate(all_paths):

    # Prepare containers for each template variant
    num_templates = len(cot_templates)
    cot_variants   = [[] for _ in range(num_templates)]
    direct_variants = [[] for _ in range(num_templates)]

    # Load the original data
    in_path = os.path.join('BRIDGE-test', task_name)
    with open(in_path, 'r', encoding='utf-8') as f:
        data = json.load(f)

    # Process each template
    for t_idx in range(num_templates):
        cot_t    = cot_templates[t_idx]
        direct_t = direct_templates[t_idx]
        new_prefix, new_list = revised_prompts[task_idx][t_idx]

        for example in data:
            instr = example.get('instruction', '')

            # 1) Replace the prefix before the first comma
            prefix, sep, rest = instr.partition(',')
            instr = new_prefix + (sep + rest if sep else '')

            # 2) If there's an updated optional list, splice it in
            if new_list:
                parts = instr.split('The optional ', 1)
                # join all but last, then tack on the revised list
                instr = ''.join(parts[:-1]) + new_list

            # 3) Split off the “Return your answer…” directive (safely)
            # before, _, after = instr.partition(
            #     'Return your answer in the following format. DO NOT GIVE ANY EXPLANATION:'
            # )
            # print(task_idx)
            split_instr = instr.split('Return your answer in the following format. DO NOT GIVE ANY EXPLANATION:', 1)

            # print(direct_t)
            direct_instr = split_instr[0] + direct_t + split_instr[1]

            # if sep2:
            #     cot_instr    = before + sep2 + cot_t    + after
            #     direct_instr = before + sep2 + direct_t + after
            # else:
            #     # fallback if that exact marker is missing
            #     cot_instr    = instr + cot_t
            #     direct_instr = instr + direct_t

            # 4) Bake into copies
            # cot_copy    = example.copy(); cot_copy['instruction']    = cot_instr
            direct_copy = example.copy(); direct_copy['instruction'] = direct_instr

            # cot_variants[t_idx].append(cot_copy)
            direct_variants[t_idx].append(direct_copy)


    # 5) Write out both the “direct” and “CoT” files
    base, ext = os.path.splitext(task_name)

    # print("TASK NAME", task_name)
    file_name = task_name.split(".test")[0]

    out_dir = os.path.join(output_base, base)

    folder_name = out_dir.split(".test")[0]

    os.makedirs(folder_name, exist_ok=True)


    for t_idx in range(num_templates):
        # e.g. 42.QUIZ.test → 42.QUIZ.prompt_0.test  and  42.QUIZ.prompt_0.cot.test
        # direct_name = f"{base}.prompt_{t_idx}{ext}"
        direct_name = f"{file_name}.prompt_{t_idx}.SFT.json"
        # cot_name    = f"{base}.prompt_{t_idx}.cot{ext}"

        with open(os.path.join(folder_name + '/', direct_name), 'w', encoding='utf-8') as fw:
            json.dump(direct_variants[t_idx], fw, indent=4, ensure_ascii=False)
            
        # with open(os.path.join(out_dir, cot_name), 'w', encoding='utf-8') as fw:
        #     json.dump(cot_variants[t_idx], fw, indent=4, ensure_ascii=False)
